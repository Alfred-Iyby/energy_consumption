# %%
import pandas as pd,os
import pmdarima as pm
from pmdarima import auto_arima
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
parent_directory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
main_directory = os.path.dirname(parent_directory)
common_records =  pd.read_csv(main_directory + '/data/common_records.csv')
# Out:
#       ID                       From        Date  Hour Participation_Phase  \
# 0  Exp_1  2020-02-01 00:00:00+00:00  2020-02-01     1             Phase_1
# 1  Exp_1  2020-02-01 01:00:00+00:00  2020-02-01     2             Phase_1
# 2  Exp_1  2020-02-01 02:00:00+00:00  2020-02-01     3             Phase_1
# 3  Exp_1  2020-02-01 03:00:00+00:00  2020-02-01     4             Phase_1
# 4  Exp_1  2020-02-01 04:00:00+00:00  2020-02-01     5             Phase_1
#
#    Demand_kWh  Temperature  Temperature24  Temperature48  Temperature72
# 0       2.393          7.6            6.1            5.0            4.4
# 1       2.056          8.2            6.2            5.1            4.4
# 2       2.258          8.4            6.3            5.3            4.5
# 3       2.535          8.4            6.4            5.4            4.5
# 4       2.042          8.2            6.5            5.5            4.6

# %%
unique_ids =  common_records["ID"].unique()
print(f"Number of households : {len(unique_ids)}")

forecasted_df = pd.DataFrame()
error_metrics_df = pd.DataFrame(columns=["ID", "MSE", "MAE", "RMSE"])

for id in unique_ids :
    temp_records = common_records[common_records["ID"]==id].reset_index(drop=True)

    y=temp_records['Demand_kWh']
    X= temp_records[["From","Temperature"]]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=False)
    model = auto_arima(y_train,
                   exogenous=X_train, 
                   suppress_warnings=True, 
                   error_action="ignore")

    print(f"Model Summary for {id} : {model.summary()}")

    n_periods = len(y_test)

    forecast = model.predict(n_periods=n_periods, exogenous=X_test)
    forecast.name = "forecast_data"
    forecast_temp_df = temp_records.join(forecast,how="left",rsuffix="_forecast")
    print(id)
    mse = mean_squared_error(y_test, forecast)
    print("Mean Squared Error:", mse)

    mae = mean_absolute_error(y_test, forecast)
    print("Mean Absolute Error:", mae)

    rmse = np.sqrt(mse)
    print("Root Mean Squared Error:", rmse)
    new_row = pd.DataFrame({
        "ID": [id],
        "MSE": [mse],
        "MAE": [mae],
        "RMSE": [rmse]
    })
    
    error_metrics_df = pd.concat([error_metrics_df, new_row], ignore_index=True)
    forecast_temp_df = forecast_temp_df[forecast_temp_df["forecast_data"].notna()]
    forecasted_df = pd.concat([forecasted_df, forecast_temp_df], ignore_index=True)


forecasted_df = forecasted_df.drop(columns=["Temperature","Temperature24","Temperature48","Temperature72","Hour","Participation_Phase"])

forecasted_df.to_csv("arima_common_records_method_1_80_20.csv",index=True)
error_metrics_df.to_csv("arima_coomon_records_method_1_80_20_error_report.csv",index=True)
# Out:
# Number of households : 688
# Model Summary for Exp_1 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(1, 1, 2)   Log Likelihood               -3352.894
# Date:                Wed, 19 Jun 2024   AIC                           6713.788
# Time:                        00:14:19   BIC                           6738.615
# Sample:                             0   HQIC                          6722.628
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6702      0.029     23.085      0.000       0.613       0.727
# ma.L1         -1.2886      0.036    -35.943      0.000      -1.359      -1.218
# ma.L2          0.3039      0.034      8.929      0.000       0.237       0.371
# sigma2         0.3645      0.007     52.934      0.000       0.351       0.378
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):               527.60
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.33   Skew:                             0.69
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_1
# Mean Squared Error: 0.8591801545627333
# Mean Absolute Error: 0.8348570714853382
# Root Mean Squared Error: 0.9269197131158304
# Model Summary for Exp_10 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(5, 1, 1)   Log Likelihood               -1642.777
# Date:                Wed, 19 Jun 2024   AIC                           3299.553
# Time:                        00:14:51   BIC                           3343.001
# Sample:                             0   HQIC                          3315.023
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7079      0.025     28.585      0.000       0.659       0.756
# ar.L2         -0.0238      0.015     -1.579      0.114      -0.053       0.006
# ar.L3         -0.0058      0.017     -0.336      0.737      -0.040       0.028
# ar.L4         -0.0716      0.018     -3.997      0.000      -0.107      -0.036
# ar.L5         -0.0280      0.018     -1.529      0.126      -0.064       0.008
# ma.L1         -0.8523      0.023    -37.053      0.000      -0.897      -0.807
# sigma2         0.1434      0.002     90.823      0.000       0.140       0.147
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              8033.96
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.89   Skew:                             0.55
# Prob(H) (two-sided):                  0.05   Kurtosis:                        10.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_10
# Mean Squared Error: 1.7185363427388651
# Mean Absolute Error: 1.1464250602329207
# Root Mean Squared Error: 1.310929571998002
# Model Summary for Exp_100 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(4, 1, 1)   Log Likelihood                  34.024
# Date:                Wed, 19 Jun 2024   AIC                            -56.048
# Time:                        00:15:46   BIC                            -18.807
# Sample:                             0   HQIC                           -42.788
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5303      0.008     64.216      0.000       0.514       0.546
# ar.L2          0.0714      0.011      6.475      0.000       0.050       0.093
# ar.L3          0.0790      0.010      8.031      0.000       0.060       0.098
# ar.L4         -0.0422      0.012     -3.533      0.000      -0.066      -0.019
# ma.L1         -0.9897      0.003   -355.850      0.000      -0.995      -0.984
# sigma2         0.0574      0.001    110.909      0.000       0.056       0.058
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             27415.81
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                             2.34
# Prob(H) (two-sided):                  0.11   Kurtosis:                        15.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_100
# Mean Squared Error: 0.10513026158176594
# Mean Absolute Error: 0.19760878639140744
# Root Mean Squared Error: 0.3242379706045637
# Model Summary for Exp_101 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(1, 1, 2)   Log Likelihood               -5216.388
# Date:                Wed, 19 Jun 2024   AIC                          10440.777
# Time:                        00:16:05   BIC                          10465.604
# Sample:                             0   HQIC                         10449.616
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6594      0.021     31.511      0.000       0.618       0.700
# ma.L1         -1.0458      0.027    -39.446      0.000      -1.098      -0.994
# ma.L2          0.0604      0.025      2.369      0.018       0.010       0.110
# sigma2         1.0074      0.019     52.159      0.000       0.970       1.045
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               361.44
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.57   Skew:                             0.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_101
# Mean Squared Error: 3.9804650994444186
# Mean Absolute Error: 1.719850232339731
# Root Mean Squared Error: 1.9951102975636257
# Model Summary for Exp_102 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(3, 1, 1)   Log Likelihood               -1135.227
# Date:                Wed, 19 Jun 2024   AIC                           2280.453
# Time:                        00:16:31   BIC                           2311.488
# Sample:                             0   HQIC                          2291.503
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0675      0.015      4.373      0.000       0.037       0.098
# ar.L2         -0.1513      0.021     -7.123      0.000      -0.193      -0.110
# ar.L3         -0.0550      0.020     -2.755      0.006      -0.094      -0.016
# ma.L1         -0.9764      0.004   -252.081      0.000      -0.984      -0.969
# sigma2         0.1087      0.001     79.611      0.000       0.106       0.111
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7405.30
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.67   Skew:                             1.95
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_102
# Mean Squared Error: 0.24171069539889034
# Mean Absolute Error: 0.4304111087149122
# Root Mean Squared Error: 0.49164081950026317
# Model Summary for Exp_104 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(2, 0, 1)   Log Likelihood               -1963.678
# Date:                Wed, 19 Jun 2024   AIC                           3937.355
# Time:                        00:16:43   BIC                           3968.391
# Sample:                             0   HQIC                          3948.405
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0150      0.007      2.252      0.024       0.002       0.028
# ar.L1          1.4900      0.030     49.157      0.000       1.431       1.549
# ar.L2         -0.5091      0.024    -21.639      0.000      -0.555      -0.463
# ma.L1         -0.9235      0.025    -36.950      0.000      -0.973      -0.875
# sigma2         0.1715      0.003     52.759      0.000       0.165       0.178
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.76   Jarque-Bera (JB):              2520.28
# Prob(Q):                              0.38   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.94   Skew:                             1.32
# Prob(H) (two-sided):                  0.28   Kurtosis:                         6.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_104
# Mean Squared Error: 0.2397647648794504
# Mean Absolute Error: 0.4038309182557272
# Root Mean Squared Error: 0.48965780385841945
# Model Summary for Exp_105 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(3, 1, 5)   Log Likelihood                2034.314
# Date:                Wed, 19 Jun 2024   AIC                          -4048.628
# Time:                        00:17:32   BIC                          -3986.560
# Sample:                             0   HQIC                         -4026.529
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -7.523e-05      0.000     -0.475      0.635      -0.000       0.000
# ar.L1         -0.7468      0.083     -8.982      0.000      -0.910      -0.584
# ar.L2          0.0917      0.050      1.844      0.065      -0.006       0.189
# ar.L3          0.2807      0.057      4.911      0.000       0.169       0.393
# ma.L1          0.1532      0.083      1.846      0.065      -0.009       0.316
# ma.L2         -0.5476      0.078     -7.015      0.000      -0.701      -0.395
# ma.L3         -0.2774      0.075     -3.704      0.000      -0.424      -0.131
# ma.L4         -0.0696      0.035     -2.016      0.044      -0.137      -0.002
# ma.L5         -0.2208      0.017    -12.726      0.000      -0.255      -0.187
# sigma2         0.0194      0.000    129.868      0.000       0.019       0.020
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.61   Jarque-Bera (JB):            201537.08
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.01   Skew:                             3.79
# Prob(H) (two-sided):                  0.00   Kurtosis:                        38.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_105
# Mean Squared Error: 0.0007811516757698613
# Mean Absolute Error: 0.02377489985927406
# Root Mean Squared Error: 0.0279490907861036
# Model Summary for Exp_106 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(3, 1, 5)   Log Likelihood               -3023.086
# Date:                Wed, 19 Jun 2024   AIC                           6066.173
# Time:                        00:18:20   BIC                           6128.242
# Sample:                             0   HQIC                          6088.272
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0002      0.000      0.615      0.538      -0.000       0.001
# ar.L1          0.1423      0.069      2.060      0.039       0.007       0.278
# ar.L2         -0.4563      0.070     -6.557      0.000      -0.593      -0.320
# ar.L3          0.4918      0.043     11.426      0.000       0.407       0.576
# ma.L1         -0.4580      0.069     -6.638      0.000      -0.593      -0.323
# ma.L2          0.3254      0.078      4.160      0.000       0.172       0.479
# ma.L3         -0.8202      0.051    -16.238      0.000      -0.919      -0.721
# ma.L4          0.0717      0.026      2.717      0.007       0.020       0.123
# ma.L5         -0.0851      0.028     -3.070      0.002      -0.139      -0.031
# sigma2         0.3038      0.005     57.956      0.000       0.294       0.314
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):              1319.93
# Prob(Q):                              0.76   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.26   Skew:                             0.79
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_106
# Mean Squared Error: 1.0877705271424585
# Mean Absolute Error: 0.9047018093518108
# Root Mean Squared Error: 1.0429623805020287
# Model Summary for Exp_107 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(1, 1, 2)   Log Likelihood               -4609.888
# Date:                Wed, 19 Jun 2024   AIC                           9227.776
# Time:                        00:18:36   BIC                           9252.603
# Sample:                             0   HQIC                          9236.616
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7052      0.019     37.313      0.000       0.668       0.742
# ma.L1         -1.0617      0.024    -44.047      0.000      -1.109      -1.014
# ma.L2          0.0743      0.023      3.225      0.001       0.029       0.119
# sigma2         0.7236      0.014     52.009      0.000       0.696       0.751
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               421.53
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             0.66
# Prob(H) (two-sided):                  0.03   Kurtosis:                         4.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_107
# Mean Squared Error: 1.8848520012451422
# Mean Absolute Error: 1.1743644587435071
# Root Mean Squared Error: 1.3728991227490612
# Model Summary for Exp_108 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(0, 1, 2)   Log Likelihood               -4546.386
# Date:                Wed, 19 Jun 2024   AIC                           9098.772
# Time:                        00:18:50   BIC                           9117.393
# Sample:                             0   HQIC                          9105.402
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6469      0.015    -42.847      0.000      -0.677      -0.617
# ma.L2         -0.3362      0.015    -22.387      0.000      -0.366      -0.307
# sigma2         0.6987      0.016     44.822      0.000       0.668       0.729
# ===================================================================================
# Ljung-Box (L1) (Q):                  32.16   Jarque-Bera (JB):               285.48
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             0.68
# Prob(H) (two-sided):                  0.03   Kurtosis:                         3.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_108
# Mean Squared Error: 1.0057459516877607
# Mean Absolute Error: 0.8344213794693184
# Root Mean Squared Error: 1.0028688606631282
# Model Summary for Exp_109 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(1, 1, 3)   Log Likelihood               -3589.759
# Date:                Wed, 19 Jun 2024   AIC                           7191.518
# Time:                        00:19:15   BIC                           7228.759
# Sample:                             0   HQIC                          7204.777
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0002      0.000     -0.664      0.506      -0.001       0.000
# ar.L1          0.5625      0.058      9.677      0.000       0.449       0.676
# ma.L1         -1.1063      0.062    -17.931      0.000      -1.227      -0.985
# ma.L2          0.1218      0.038      3.174      0.002       0.047       0.197
# ma.L3          0.0088      0.029      0.306      0.760      -0.048       0.065
# sigma2         0.3961      0.010     40.013      0.000       0.377       0.416
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):               242.16
# Prob(Q):                              0.74   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.07   Skew:                             0.63
# Prob(H) (two-sided):                  0.21   Kurtosis:                         3.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_109
# Mean Squared Error: 0.6425608211488307
# Mean Absolute Error: 0.698007588308412
# Root Mean Squared Error: 0.801598915386511
# Model Summary for Exp_11 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(2, 1, 2)   Log Likelihood               -2953.580
# Date:                Wed, 19 Jun 2024   AIC                           5919.160
# Time:                        00:19:39   BIC                           5956.401
# Sample:                             0   HQIC                          5932.419
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1.162e-05      0.000      0.087      0.931      -0.000       0.000
# ar.L1          0.9876      0.095     10.397      0.000       0.801       1.174
# ar.L2         -0.1414      0.063     -2.243      0.025      -0.265      -0.018
# ma.L1         -1.4243      0.094    -15.179      0.000      -1.608      -1.240
# ma.L2          0.4373      0.090      4.841      0.000       0.260       0.614
# sigma2         0.2966      0.005     58.562      0.000       0.287       0.306
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.41   Jarque-Bera (JB):              2353.09
# Prob(Q):                              0.52   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.41   Skew:                             0.92
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_11
# Mean Squared Error: 1.1562390934269982
# Mean Absolute Error: 0.9120241166849036
# Root Mean Squared Error: 1.0752855869149358
# Model Summary for Exp_110 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(2, 1, 4)   Log Likelihood               -2466.977
# Date:                Wed, 19 Jun 2024   AIC                           4949.953
# Time:                        00:20:20   BIC                           4999.608
# Sample:                             0   HQIC                          4967.633
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3.086e-05      0.000      0.113      0.910      -0.001       0.001
# ar.L1          0.0555      0.134      0.413      0.680      -0.208       0.319
# ar.L2          0.2999      0.104      2.873      0.004       0.095       0.504
# ma.L1         -0.5404      0.134     -4.021      0.000      -0.804      -0.277
# ma.L2         -0.3923      0.164     -2.397      0.017      -0.713      -0.072
# ma.L3          0.0895      0.039      2.266      0.023       0.012       0.167
# ma.L4         -0.1275      0.022     -5.751      0.000      -0.171      -0.084
# sigma2         0.2256      0.005     46.419      0.000       0.216       0.235
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):               552.60
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             0.76
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_110
# Mean Squared Error: 0.3332693728418329
# Mean Absolute Error: 0.4744869570139441
# Root Mean Squared Error: 0.5772948751217465
# Model Summary for Exp_112 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(2, 1, 2)   Log Likelihood               -3623.317
# Date:                Wed, 19 Jun 2024   AIC                           7256.634
# Time:                        00:20:45   BIC                           7287.669
# Sample:                             0   HQIC                          7267.684
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1255      0.180     -0.696      0.486      -0.479       0.228
# ar.L2          0.2440      0.062      3.915      0.000       0.122       0.366
# ma.L1         -0.4934      0.182     -2.707      0.007      -0.851      -0.136
# ma.L2         -0.4713      0.177     -2.658      0.008      -0.819      -0.124
# sigma2         0.4224      0.007     61.370      0.000       0.409       0.436
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1550.40
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                             1.12
# Prob(H) (two-sided):                  0.99   Kurtosis:                         5.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_112
# Mean Squared Error: 1.9490326056635996
# Mean Absolute Error: 1.2880821546888004
# Root Mean Squared Error: 1.3960775786694661
# Model Summary for Exp_113 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(2, 1, 2)   Log Likelihood               -4095.272
# Date:                Wed, 19 Jun 2024   AIC                           8200.544
# Time:                        00:21:05   BIC                           8231.578
# Sample:                             0   HQIC                          8211.594
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5376      0.054      9.986      0.000       0.432       0.643
# ar.L2         -0.1265      0.042     -3.033      0.002      -0.208      -0.045
# ma.L1         -0.6842      0.055    -12.551      0.000      -0.791      -0.577
# ma.L2         -0.2685      0.054     -4.974      0.000      -0.374      -0.163
# sigma2         0.5465      0.008     65.530      0.000       0.530       0.563
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2268.91
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.05   Skew:                             1.29
# Prob(H) (two-sided):                  0.36   Kurtosis:                         5.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_113
# Mean Squared Error: 2.9639978095055945
# Mean Absolute Error: 1.5006392329614695
# Root Mean Squared Error: 1.7216265011626635
# Model Summary for Exp_114 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(2, 1, 3)   Log Likelihood               -5543.595
# Date:                Wed, 19 Jun 2024   AIC                          11099.189
# Time:                        00:21:59   BIC                          11136.430
# Sample:                             0   HQIC                         11112.449
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5419      0.019    -28.492      0.000      -0.579      -0.505
# ar.L2          0.4519      0.019     23.610      0.000       0.414       0.489
# ma.L1          0.3457      0.019     18.041      0.000       0.308       0.383
# ma.L2         -0.9311      0.008   -112.038      0.000      -0.947      -0.915
# ma.L3         -0.2928      0.016    -18.359      0.000      -0.324      -0.262
# sigma2         1.2044      0.014     83.453      0.000       1.176       1.233
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):              6912.82
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.64   Skew:                             1.18
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_114
# Mean Squared Error: 4.7983971384741375
# Mean Absolute Error: 1.8527696715818076
# Root Mean Squared Error: 2.1905243980549813
# Model Summary for Exp_115 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(2, 1, 1)   Log Likelihood               -3781.414
# Date:                Wed, 19 Jun 2024   AIC                           7570.827
# Time:                        00:22:17   BIC                           7595.655
# Sample:                             0   HQIC                          7579.667
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4358      0.014     30.095      0.000       0.407       0.464
# ar.L2         -0.0489      0.017     -2.920      0.003      -0.082      -0.016
# ma.L1         -0.9783      0.004   -254.951      0.000      -0.986      -0.971
# sigma2         0.4604      0.008     59.405      0.000       0.445       0.476
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1282.90
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.05   Skew:                             1.11
# Prob(H) (two-sided):                  0.36   Kurtosis:                         4.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_115
# Mean Squared Error: 0.5292151880666854
# Mean Absolute Error: 0.5351426436515684
# Root Mean Squared Error: 0.7274717781925877
# Model Summary for Exp_116 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(0, 1, 3)   Log Likelihood               -2532.400
# Date:                Wed, 19 Jun 2024   AIC                           5072.800
# Time:                        00:22:38   BIC                           5097.627
# Sample:                             0   HQIC                          5081.640
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.2457      0.010    -24.135      0.000      -0.266      -0.226
# ma.L2         -0.1144      0.018     -6.510      0.000      -0.149      -0.080
# ma.L3         -0.1438      0.020     -7.065      0.000      -0.184      -0.104
# sigma2         0.2331      0.002    100.777      0.000       0.229       0.238
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.72   Jarque-Bera (JB):             16289.55
# Prob(Q):                              0.40   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.77
# Prob(H) (two-sided):                  0.60   Kurtosis:                        12.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_116
# Mean Squared Error: 0.44974677597269835
# Mean Absolute Error: 0.4927746574576408
# Root Mean Squared Error: 0.6706316246440354
# Model Summary for Exp_117 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(5, 1, 4)   Log Likelihood               -2921.666
# Date:                Wed, 19 Jun 2024   AIC                           5863.332
# Time:                        00:23:28   BIC                           5925.401
# Sample:                             0   HQIC                          5885.432
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2214      0.109     -2.024      0.043      -0.436      -0.007
# ar.L2          1.1196      0.102     11.028      0.000       0.921       1.319
# ar.L3          0.0795      0.088      0.904      0.366      -0.093       0.252
# ar.L4         -0.3315      0.071     -4.638      0.000      -0.472      -0.191
# ar.L5         -0.0531      0.018     -2.961      0.003      -0.088      -0.018
# ma.L1         -0.0876      0.108     -0.807      0.419      -0.300       0.125
# ma.L2         -1.4782      0.111    -13.263      0.000      -1.697      -1.260
# ma.L3          0.0950      0.108      0.879      0.379      -0.117       0.307
# ma.L4          0.5069      0.110      4.622      0.000       0.292       0.722
# sigma2         0.2866      0.003     83.000      0.000       0.280       0.293
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):              6873.71
# Prob(Q):                              0.76   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                             1.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_117
# Mean Squared Error: 0.9021689854694244
# Mean Absolute Error: 0.8645004232374011
# Root Mean Squared Error: 0.9498257658483604
# Model Summary for Exp_118 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(1, 1, 3)   Log Likelihood               -3750.766
# Date:                Wed, 19 Jun 2024   AIC                           7511.532
# Time:                        00:23:56   BIC                           7542.566
# Sample:                             0   HQIC                          7522.581
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6688      0.033     20.337      0.000       0.604       0.733
# ma.L1         -0.9681      0.037    -26.347      0.000      -1.040      -0.896
# ma.L2         -0.0902      0.024     -3.727      0.000      -0.138      -0.043
# ma.L3          0.0681      0.027      2.567      0.010       0.016       0.120
# sigma2         0.4528      0.007     60.989      0.000       0.438       0.467
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1253.65
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.99   Skew:                             1.00
# Prob(H) (two-sided):                  0.91   Kurtosis:                         5.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_118
# Mean Squared Error: 1.1362562868938042
# Mean Absolute Error: 0.9354828014017489
# Root Mean Squared Error: 1.0659532292243428
# Model Summary for Exp_119 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(1, 1, 2)   Log Likelihood               -4169.146
# Date:                Wed, 19 Jun 2024   AIC                           8346.293
# Time:                        00:24:09   BIC                           8371.120
# Sample:                             0   HQIC                          8355.133
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5626      0.026     21.613      0.000       0.512       0.614
# ma.L1         -0.9222      0.029    -31.890      0.000      -0.979      -0.865
# ma.L2         -0.0444      0.026     -1.692      0.091      -0.096       0.007
# sigma2         0.5690      0.011     53.786      0.000       0.548       0.590
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               624.16
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.88   Skew:                             0.82
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_119
# Mean Squared Error: 1.1411960753233523
# Mean Absolute Error: 0.9234151288434763
# Root Mean Squared Error: 1.0682677919526322
# Model Summary for Exp_120 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(0, 1, 0)   Log Likelihood               -2879.950
# Date:                Wed, 19 Jun 2024   AIC                           5761.899
# Time:                        00:24:14   BIC                           5768.106
# Sample:                             0   HQIC                          5764.109
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.2818      0.004     63.648      0.000       0.273       0.290
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.14   Jarque-Bera (JB):               895.89
# Prob(Q):                              0.29   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.30   Skew:                             0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_120
# Mean Squared Error: 2.200128282442748
# Mean Absolute Error: 1.3214252998909486
# Root Mean Squared Error: 1.483282940791388
# Model Summary for Exp_121 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(1, 1, 5)   Log Likelihood               -1912.917
# Date:                Wed, 19 Jun 2024   AIC                           3839.834
# Time:                        00:24:56   BIC                           3883.282
# Sample:                             0   HQIC                          3855.304
#                                - 3667
# Covariance Type:                  opg
# ...
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1.567e-05      0.000      0.061      0.951      -0.000       0.001
# ar.L1         -0.3301      0.321     -1.029      0.303      -0.959       0.298
# ar.L2         -0.0062      0.152     -0.041      0.968      -0.304       0.292
# ma.L1         -0.2396      0.321     -0.747      0.455      -0.868       0.389
# ma.L2         -0.4121      0.302     -1.362      0.173      -1.005       0.181
# ma.L3         -0.2131      0.086     -2.477      0.013      -0.382      -0.045
# ma.L4         -0.1024      0.040     -2.557      0.011      -0.181      -0.024
# sigma2         0.0462      0.001     54.853      0.000       0.045       0.048
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.83   Jarque-Bera (JB):             25542.27
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.32   Skew:                             3.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_91
# Mean Squared Error: 0.06046996775071595
# Mean Absolute Error: 0.16852544604054132
# Root Mean Squared Error: 0.24590642071876845
# Model Summary for Exp_92 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -5945.802
# Date:                Wed, 19 Jun 2024   AIC                          11895.604
# Time:                        05:31:01   BIC                          11908.018
# Sample:                             0   HQIC                         11900.024
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.2312      0.017    -14.002      0.000      -0.264      -0.199
# sigma2         1.5006      0.033     45.660      0.000       1.436       1.565
# ===================================================================================
# Ljung-Box (L1) (Q):                  14.63   Jarque-Bera (JB):                56.08
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             0.26
# Prob(H) (two-sided):                  0.63   Kurtosis:                         3.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_92
# Mean Squared Error: 1.9190166460711167
# Mean Absolute Error: 1.2326794039272728
# Root Mean Squared Error: 1.3852857633250681
# Model Summary for Exp_94 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(2, 1, 2)   Log Likelihood               -2904.869
# Date:                Wed, 19 Jun 2024   AIC                           5819.739
# Time:                        05:31:23   BIC                           5850.773
# Sample:                             0   HQIC                          5830.788
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6542      0.023     72.778      0.000       1.610       1.699
# ar.L2         -0.7089      0.016    -44.678      0.000      -0.740      -0.678
# ma.L1         -1.8788      0.024    -77.297      0.000      -1.926      -1.831
# ma.L2          0.8845      0.024     37.386      0.000       0.838       0.931
# sigma2         0.2851      0.004     71.249      0.000       0.277       0.293
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.20   Jarque-Bera (JB):              2639.32
# Prob(Q):                              0.66   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             0.89
# Prob(H) (two-sided):                  0.11   Kurtosis:                         6.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_94
# Mean Squared Error: 3.397944379443616
# Mean Absolute Error: 1.7119136546042224
# Root Mean Squared Error: 1.843351398796121
# Model Summary for Exp_95 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(1, 1, 4)   Log Likelihood               -1032.994
# Date:                Wed, 19 Jun 2024   AIC                           2079.987
# Time:                        05:31:56   BIC                           2123.435
# Sample:                             0   HQIC                          2095.457
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -2.299e-05      0.000     -0.164      0.870      -0.000       0.000
# ar.L1          0.7080      0.029     24.590      0.000       0.652       0.764
# ma.L1         -0.9193      0.030    -30.598      0.000      -0.978      -0.860
# ma.L2          0.0377      0.022      1.746      0.081      -0.005       0.080
# ma.L3          0.0073      0.024      0.308      0.758      -0.039       0.053
# ma.L4         -0.1052      0.022     -4.690      0.000      -0.149      -0.061
# sigma2         0.1003      0.001     68.360      0.000       0.097       0.103
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.15   Jarque-Bera (JB):              5413.72
# Prob(Q):                              0.28   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.82   Skew:                             0.92
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_95
# Mean Squared Error: 0.7459469728228132
# Mean Absolute Error: 0.7537494756099319
# Root Mean Squared Error: 0.8636822174983187
# Model Summary for Exp_96 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -338.855
# Date:                Wed, 19 Jun 2024   AIC                            681.710
# Time:                        05:32:07   BIC                            694.123
# Sample:                             0   HQIC                           686.130
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5828      0.007    -83.038      0.000      -0.597      -0.569
# sigma2         0.0704      0.001    112.624      0.000       0.069       0.072
# ===================================================================================
# Ljung-Box (L1) (Q):                  50.14   Jarque-Bera (JB):             24997.86
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.34   Skew:                             2.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_96
# Mean Squared Error: 0.06905847924823408
# Mean Absolute Error: 0.19212265637970405
# Root Mean Squared Error: 0.26278980050267187
# Model Summary for Exp_97 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -3604.319
# Date:                Wed, 19 Jun 2024   AIC                           7212.637
# Time:                        05:32:12   BIC                           7225.051
# Sample:                             0   HQIC                          7217.057
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6389      0.011    -58.899      0.000      -0.660      -0.618
# sigma2         0.4182      0.007     59.533      0.000       0.404       0.432
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               927.07
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                             0.76
# Prob(H) (two-sided):                  0.29   Kurtosis:                         4.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_97
# Mean Squared Error: 5.015868318776801
# Mean Absolute Error: 2.08376493813183
# Root Mean Squared Error: 2.2396134306564606
# Model Summary for Exp_98 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(2, 1, 1)   Log Likelihood                -714.776
# Date:                Wed, 19 Jun 2024   AIC                           1437.553
# Time:                        05:32:34   BIC                           1462.380
# Sample:                             0   HQIC                          1446.393
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7242      0.009     79.672      0.000       0.706       0.742
# ar.L2         -0.0589      0.010     -6.159      0.000      -0.078      -0.040
# ma.L1         -0.9845      0.003   -364.798      0.000      -0.990      -0.979
# sigma2         0.0864      0.001    127.361      0.000       0.085       0.088
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             45504.33
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                             2.86
# Prob(H) (two-sided):                  0.33   Kurtosis:                        19.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_98
# Mean Squared Error: 0.2489819886592688
# Mean Absolute Error: 0.38331541308234796
# Root Mean Squared Error: 0.4989809501967673
# Model Summary for Exp_99 :                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3667
# Model:               SARIMAX(5, 1, 3)   Log Likelihood                -239.363
# Date:                Wed, 19 Jun 2024   AIC                            496.725
# Time:                        05:33:24   BIC                            552.587
# Sample:                             0   HQIC                           516.615
#                                - 3667
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8923      0.137     -6.511      0.000      -1.161      -0.624
# ar.L2          0.2941      0.084      3.501      0.000       0.129       0.459
# ar.L3          0.5537      0.085      6.506      0.000       0.387       0.720
# ar.L4          0.0946      0.057      1.666      0.096      -0.017       0.206
# ar.L5          0.0678      0.026      2.621      0.009       0.017       0.119
# ma.L1          0.1347      0.137      0.984      0.325      -0.133       0.403
# ma.L2         -0.7343      0.034    -21.725      0.000      -0.801      -0.668
# ma.L3         -0.3424      0.107     -3.189      0.001      -0.553      -0.132
# sigma2         0.0667      0.001     91.204      0.000       0.065       0.068
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             11186.52
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.18   Skew:                             1.48
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Exp_99
# Mean Squared Error: 0.523891567224999
# Mean Absolute Error: 0.6697674231844413
# Root Mean Squared Error: 0.7238035418709962
