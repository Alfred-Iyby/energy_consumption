# %%
import os, pandas as pd
import numpy as np
from pmdarima import auto_arima
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
parent_directory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
main_directory = os.path.dirname(parent_directory)
phase_1 =  pd.read_csv(main_directory + '/data/phase_1_data_with_survey.csv')
phase_1
# Out:
#             ID                       From        Date  Hour  \
# 0       Exp_62  2020-02-01 00:00:00+00:00  2020-02-01     1
# 1       Exp_62  2020-02-01 01:00:00+00:00  2020-02-01     2
# 2       Exp_62  2020-02-01 02:00:00+00:00  2020-02-01     3
# 3       Exp_62  2020-02-01 03:00:00+00:00  2020-02-01     4
# 4       Exp_62  2020-02-01 04:00:00+00:00  2020-02-01     5
# ...        ...                        ...         ...   ...
# 64795  Exp_460  2020-03-20 19:00:00+00:00  2020-03-20    20
# 64796  Exp_460  2020-03-20 20:00:00+00:00  2020-03-20    21
# 64797  Exp_460  2020-03-20 21:00:00+00:00  2020-03-20    22
# 64798  Exp_460  2020-03-20 22:00:00+00:00  2020-03-20    23
# 64799  Exp_460  2020-03-20 23:00:00+00:00  2020-03-20    24
#
#       Participation_Phase  Demand_kWh  Temperature   home_size electric_car  \
# 0                 Phase_1       1.925          7.6  120-159 m2          Yes
# 1                 Phase_1       2.002          8.2  120-159 m2          Yes
# 2                 Phase_1       2.019          8.4  120-159 m2          Yes
# 3                 Phase_1       2.205          8.4  120-159 m2          Yes
# 4                 Phase_1       2.834          8.2  120-159 m2          Yes
# ...                   ...         ...          ...         ...          ...
# 64795             Phase_1       0.852          4.0    60-79 m2          Yes
# 64796             Phase_1       0.705          3.0    60-79 m2          Yes
# 64797             Phase_1       0.781          2.5    60-79 m2          Yes
# 64798             Phase_1       0.657          2.2    60-79 m2          Yes
# 64799             Phase_1       0.626          1.9    60-79 m2          Yes
#
#        no_of_people  electrically_heated
# 0                 3                 True
# 1                 3                 True
# 2                 3                 True
# 3                 3                 True
# 4                 3                 True
# ...             ...                  ...
# 64795             1                False
# 64796             1                False
# 64797             1                False
# 64798             1                False
# 64799             1                False
#
# [64800 rows x 11 columns]

# %%
phase_1 = pd.get_dummies(phase_1, columns=['home_size'])
phase_1.head()
# Out:
#        ID                       From        Date  Hour Participation_Phase  \
# 0  Exp_62  2020-02-01 00:00:00+00:00  2020-02-01     1             Phase_1
# 1  Exp_62  2020-02-01 01:00:00+00:00  2020-02-01     2             Phase_1
# 2  Exp_62  2020-02-01 02:00:00+00:00  2020-02-01     3             Phase_1
# 3  Exp_62  2020-02-01 03:00:00+00:00  2020-02-01     4             Phase_1
# 4  Exp_62  2020-02-01 04:00:00+00:00  2020-02-01     5             Phase_1
#
#    Demand_kWh  Temperature electric_car  no_of_people  electrically_heated  \
# 0       1.925          7.6          Yes             3                 True
# 1       2.002          8.2          Yes             3                 True
# 2       2.019          8.4          Yes             3                 True
# 3       2.205          8.4          Yes             3                 True
# 4       2.834          8.2          Yes             3                 True
#
#    home_size_100-119 m2  home_size_120-159 m2  home_size_160 m2 or larger  \
# 0                 False                  True                       False
# 1                 False                  True                       False
# 2                 False                  True                       False
# 3                 False                  True                       False
# 4                 False                  True                       False
#
#    home_size_30-49 m2  home_size_50-59 m2  home_size_60-79 m2  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    home_size_80-99 m2
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False

# %% [markdown]
# 75/25

# %%
y=phase_1['Demand_kWh']
X= phase_1[["From","Temperature","home_size_100-119 m2","home_size_120-159 m2","home_size_160 m2 or larger","home_size_30-49 m2","home_size_50-59 m2","home_size_60-79 m2","home_size_80-99 m2","electric_car","electrically_heated"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=False)
X_train.head()
# Out:
#                         From  Temperature  home_size_100-119 m2  \
# 0  2020-02-01 00:00:00+00:00          7.6                 False
# 1  2020-02-01 01:00:00+00:00          8.2                 False
# 2  2020-02-01 02:00:00+00:00          8.4                 False
# 3  2020-02-01 03:00:00+00:00          8.4                 False
# 4  2020-02-01 04:00:00+00:00          8.2                 False
#
#    home_size_120-159 m2  home_size_160 m2 or larger  home_size_30-49 m2  \
# 0                  True                       False               False
# 1                  True                       False               False
# 2                  True                       False               False
# 3                  True                       False               False
# 4                  True                       False               False
#
#    home_size_50-59 m2  home_size_60-79 m2  home_size_80-99 m2 electric_car  \
# 0               False               False               False          Yes
# 1               False               False               False          Yes
# 2               False               False               False          Yes
# 3               False               False               False          Yes
# 4               False               False               False          Yes
#
#    electrically_heated
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True

# %%
model = auto_arima(y_train,
                   exogenous=X_train, 
                   suppress_warnings=True, 
                   error_action="ignore")

print(model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                48600
# Model:               SARIMAX(2, 1, 5)   Log Likelihood              -56002.850
# Date:                Thu, 04 Jul 2024   AIC                         112021.700
# Time:                        00:48:54   BIC                         112092.031
# Sample:                             0   HQIC                        112043.760
#                               - 48600
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6438      0.003    513.903      0.000       1.638       1.650
# ar.L2         -0.9198      0.003   -313.507      0.000      -0.926      -0.914
# ma.L1         -2.0191      0.005   -444.361      0.000      -2.028      -2.010
# ma.L2          1.2527      0.008    149.959      0.000       1.236       1.269
# ma.L3         -0.0110      0.009     -1.229      0.219      -0.028       0.007
# ma.L4         -0.0535      0.008     -6.726      0.000      -0.069      -0.038
# ma.L5         -0.1466      0.004    -39.604      0.000      -0.154      -0.139
# sigma2         0.5799      0.002    284.670      0.000       0.576       0.584
# ===================================================================================
# Ljung-Box (L1) (Q):                  14.88   Jarque-Bera (JB):             53636.09
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.51   Skew:                             0.94
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
n_periods = len(y_test)

forecast = model.predict(n_periods=n_periods, exogenous=X_test)
forecast.name = "forecast_data"
forecast_df = phase_1.join(forecast,how="left",rsuffix="_forecast")

print("Predicted values:", forecast)

mse = mean_squared_error(y_test, forecast)
print("Mean Squared Error:", mse)

mae = mean_absolute_error(y_test, forecast)
print("Mean Absolute Error:", mae)

rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Predicted values: 48600    3.013734
# 48601    2.808083
# 48602    2.883354
# 48603    3.001698
# 48604    3.150471
#            ...
# 64795    3.146303
# 64796    3.146303
# 64797    3.146303
# 64798    3.146303
# 64799    3.146303
# Name: forecast_data, Length: 16200, dtype: float64
# Mean Squared Error: 4.583185598758996
# Mean Absolute Error: 1.6763647818690621
# Root Mean Squared Error: 2.1408375928031056

# %%
df = forecast_df[forecast_df["forecast_data"].notna()]
df = df.drop(columns=["Temperature","Hour","Participation_Phase"])

df.to_csv(parent_directory+"/Arima/predictions/phase_1_with_survey_data/arima_phase_1_with_survey_method_2_75_25.csv",index=True)

# %% [markdown]
# 80 / 20 Ratio

# %%
# phase_1.set_index('From',inplace=True)

y=phase_1['Demand_kWh']
X= phase_1[["From","Temperature","home_size","electric_car","electrically_heated"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
X_train.head()
# Out:
#                         From  Temperature   home_size electric_car  \
# 0  2020-02-01 00:00:00+00:00          7.6  120-159 m2          Yes
# 1  2020-02-01 01:00:00+00:00          8.2  120-159 m2          Yes
# 2  2020-02-01 02:00:00+00:00          8.4  120-159 m2          Yes
# 3  2020-02-01 03:00:00+00:00          8.4  120-159 m2          Yes
# 4  2020-02-01 04:00:00+00:00          8.2  120-159 m2          Yes
#
#   electrically_heated
# 0                 Yes
# 1                 Yes
# 2                 Yes
# 3                 Yes
# 4                 Yes

# %%
model = auto_arima(y_train,
                   exogenous=X_train, 
                   suppress_warnings=True, 
                   error_action="ignore")

print(model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                51840
# Model:               SARIMAX(2, 1, 2)   Log Likelihood              -61811.783
# Date:                Thu, 20 Jun 2024   AIC                         123633.566
# Time:                        20:52:10   BIC                         123677.845
# Sample:                             0   HQIC                        123647.413
#                               - 51840
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4050      0.052      7.774      0.000       0.303       0.507
# ar.L2          0.1047      0.033      3.155      0.002       0.040       0.170
# ma.L1         -0.7172      0.052    -13.838      0.000      -0.819      -0.616
# ma.L2         -0.2496      0.051     -4.927      0.000      -0.349      -0.150
# sigma2         0.6356      0.002    366.977      0.000       0.632       0.639
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            183964.69
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.68   Skew:                             1.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
n_periods = len(y_test)

forecast = model.predict(n_periods=n_periods, exogenous=X_test)
forecast.name = "forecast_data"
forecast_df = phase_1.join(forecast,how="left",rsuffix="_forecast")

print("Predicted values:", forecast)

mse = mean_squared_error(y_test, forecast)
print("Mean Squared Error:", mse)

mae = mean_absolute_error(y_test, forecast)
print("Mean Absolute Error:", mae)

rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Predicted values: 51840    3.659116
# 51841    3.864583
# 51842    3.977962
# 51843    4.045392
# 51844    4.084571
#            ...
# 64795    4.139698
# 64796    4.139698
# 64797    4.139698
# 64798    4.139698
# 64799    4.139698
# Name: forecast_data, Length: 12960, dtype: float64
# Mean Squared Error: 7.661067454593768
# Mean Absolute Error: 2.3545304953842376
# Root Mean Squared Error: 2.767863337412772

# %%
df = forecast_df[forecast_df["forecast_data"].notna()]
df = df.drop(columns=["Temperature","Hour","Participation_Phase"])

df.to_csv(parent_directory+"/Arima/predictions/phase_1_with_survey_data/arima_phase_1_with_survey_method_2_80_20.csv",index=True)

# %% [markdown]
# 60 / 40 Ratio

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, shuffle=False)
X_train.head()
# Out:
#                         From  Temperature   home_size electric_car  \
# 0  2020-02-01 00:00:00+00:00          7.6  120-159 m2          Yes
# 1  2020-02-01 01:00:00+00:00          8.2  120-159 m2          Yes
# 2  2020-02-01 02:00:00+00:00          8.4  120-159 m2          Yes
# 3  2020-02-01 03:00:00+00:00          8.4  120-159 m2          Yes
# 4  2020-02-01 04:00:00+00:00          8.2  120-159 m2          Yes
#
#   electrically_heated
# 0                 Yes
# 1                 Yes
# 2                 Yes
# 3                 Yes
# 4                 Yes

# %%
model = auto_arima(y_train,
                   exogenous=X_train, 
                   suppress_warnings=True, 
                   error_action="ignore")

print(model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                38880
# Model:               SARIMAX(2, 1, 2)   Log Likelihood              -46744.646
# Date:                Thu, 20 Jun 2024   AIC                          93499.292
# Time:                        22:55:40   BIC                          93542.134
# Sample:                             0   HQIC                         93512.871
#                               - 38880
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3747      0.070      5.391      0.000       0.238       0.511
# ar.L2          0.0916      0.042      2.172      0.030       0.009       0.174
# ma.L1         -0.7205      0.069    -10.413      0.000      -0.856      -0.585
# ma.L2         -0.2392      0.067     -3.557      0.000      -0.371      -0.107
# sigma2         0.6484      0.003    252.241      0.000       0.643       0.653
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             42373.96
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                             0.95
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
n_periods = len(y_test)

forecast = model.predict(n_periods=n_periods, exogenous=X_test)
forecast.name = "forecast_data"
forecast_df = phase_1.join(forecast,how="left",rsuffix="_forecast")

print("Predicted values:", forecast)

mse = mean_squared_error(y_test, forecast)
print("Mean Squared Error:", mse)

mae = mean_absolute_error(y_test, forecast)
print("Mean Absolute Error:", mae)

rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Predicted values: 38880    1.386980
# 38881    1.708181
# 38882    1.853826
# 38883    1.937828
# 38884    1.982649
#            ...
# 64795    2.036235
# 64796    2.036235
# 64797    2.036235
# 64798    2.036235
# 64799    2.036235
# Name: forecast_data, Length: 25920, dtype: float64
# Mean Squared Error: 3.3959806537074564
# Mean Absolute Error: 1.4482561156725355
# Root Mean Squared Error: 1.842818670870104

# %%
df = forecast_df[forecast_df["forecast_data"].notna()]
df = df.drop(columns=["Temperature","Hour","Participation_Phase"])

df.to_csv(parent_directory+"/Arima/predictions/phase_1_with_survey_data/arima_phase_1_with_survey_method_2_60_40.csv",index=True)

# %% [markdown]
# 50 / 50 Ratio

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, shuffle=False)
X_train.head()
# Out:
#                         From  Temperature   home_size electric_car  \
# 0  2020-02-01 00:00:00+00:00          7.6  120-159 m2          Yes
# 1  2020-02-01 01:00:00+00:00          8.2  120-159 m2          Yes
# 2  2020-02-01 02:00:00+00:00          8.4  120-159 m2          Yes
# 3  2020-02-01 03:00:00+00:00          8.4  120-159 m2          Yes
# 4  2020-02-01 04:00:00+00:00          8.2  120-159 m2          Yes
#
#   electrically_heated
# 0                 Yes
# 1                 Yes
# 2                 Yes
# 3                 Yes
# 4                 Yes

# %%
model = auto_arima(y_train,
                   exogenous=X_train, 
                   suppress_warnings=True, 
                   error_action="ignore")

print(model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                32400
# Model:               SARIMAX(2, 1, 5)   Log Likelihood              -40470.684
# Date:                Thu, 20 Jun 2024   AIC                          80957.368
# Time:                        23:00:09   BIC                          81024.455
# Sample:                             0   HQIC                         80978.815
#                               - 32400
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6944      0.002    717.117      0.000       1.690       1.699
# ar.L2         -0.9648      0.002   -425.155      0.000      -0.969      -0.960
# ma.L1         -2.0849      0.005   -428.964      0.000      -2.094      -2.075
# ma.L2          1.3247      0.010    127.219      0.000       1.304       1.345
# ma.L3         -0.0071      0.012     -0.586      0.558      -0.031       0.017
# ma.L4         -0.0708      0.011     -6.684      0.000      -0.092      -0.050
# ma.L5         -0.1374      0.005    -29.679      0.000      -0.146      -0.128
# sigma2         0.7129      0.003    214.072      0.000       0.706       0.719
# ===================================================================================
# Ljung-Box (L1) (Q):                   9.94   Jarque-Bera (JB):             25169.69
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.70   Skew:                             0.90
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
n_periods = len(y_test)

forecast = model.predict(n_periods=n_periods, exogenous=X_test)
forecast.name = "forecast_data"
forecast_df = phase_1.join(forecast,how="left",rsuffix="_forecast")

print("Predicted values:", forecast)

mse = mean_squared_error(y_test, forecast)
print("Mean Squared Error:", mse)

mae = mean_absolute_error(y_test, forecast)
print("Mean Absolute Error:", mae)

rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Predicted values: 32400    3.379051
# 32401    3.221782
# 32402    3.152823
# 32403    3.182417
# 32404    3.280650
#            ...
# 64795    3.440121
# 64796    3.440121
# 64797    3.440121
# 64798    3.440121
# 64799    3.440121
# Name: forecast_data, Length: 32400, dtype: float64
# Mean Squared Error: 4.832084028440449
# Mean Absolute Error: 1.8604104163409247
# Root Mean Squared Error: 2.198200179337735

# %%
df = forecast_df[forecast_df["forecast_data"].notna()]
df = df.drop(columns=["Temperature","Hour","Participation_Phase"])

df.to_csv(parent_directory+"/Arima/predictions/phase_1_with_survey_data/arima_phase_1_with_survey_method_2_50_50.csv",index=True)
