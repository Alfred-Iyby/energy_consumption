# %%
80:20

# %%
import pandas as pd
import pmdarima as pm
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import LabelEncoder
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# Load your dataset (assuming it is a CSV file)
df = pd.read_csv('phase_2_data_with_survey.csv')

# Convert 'Date' and 'Hour' columns to a datetime object
df['Datetime'] = pd.to_datetime(df['Date']) + pd.to_timedelta(df['Hour'], unit='h')

# Set 'Datetime' as index
df.set_index('Datetime', inplace=True)

# Encode categorical variables
label_encoder = LabelEncoder()
df['home_size_encoded'] = label_encoder.fit_transform(df['home_size'])
df['electric_car_encoded'] = df['electric_car'].map({'Yes': 1, 'No': 0})
df['electrically_heated_encoded'] = df['electrically_heated'].map({'Yes': 1, 'No': 0})

# List of exogenous variables
exog_vars = ['Temperature', 'home_size_encoded', 'electric_car_encoded', 'electrically_heated_encoded','no_of_people']

def fit_forecast_arima(df, split_ratio=0.8):
    ids = df['ID'].unique()[:1000]
    forecasts = []
    i = 1
    for id_ in ids:
        print(f"{i} Processing ID: {id_}")
        i += 1
        df_id = df[df['ID'] == id_].sort_index()

        # Split the data into train and test
        split_index = int(len(df_id) * split_ratio)
        train = df_id.iloc[:split_index]
        test = df_id.iloc[split_index:]

        # Fit the ARIMA model
        model = auto_arima(train['Demand_kWh'],
                           exogenous=train[exog_vars],
                           seasonal=False,
                           stepwise=True,
                           suppress_warnings=True,
                           trace=False)

        # Forecast
        n_periods = len(test)
        forecast = model.predict(n_periods=n_periods, exogenous=test[exog_vars])

        # Store the forecast and actual values
        forecast_df = pd.DataFrame({
            'ID': id_,
            'Datetime': test.index,
            'Actual_Demand': test['Demand_kWh'],
            'Predicted_Demand': forecast
        })

        forecasts.append(forecast_df)

    return pd.concat(forecasts)

# Run the forecasting function
results_df = fit_forecast_arima(df)

# Calculate overall error metrics
mse = mean_squared_error(results_df['Actual_Demand'], results_df['Predicted_Demand'])
mae = mean_absolute_error(results_df['Actual_Demand'], results_df['Predicted_Demand'])
rmse = np.sqrt(mse)

print(f"Overall MSE: {mse}")
print(f"Overall MAE: {mae}")
print(f"Overall RMSE: {rmse}")

# Write the results to a file
results_df['Date'] = results_df['Datetime'].dt.date
results_df['Hour'] = results_df['Datetime'].dt.hour
results_df = results_df[['ID', 'Date', 'Hour', 'Actual_Demand', 'Predicted_Demand']]
results_df.to_csv('arima_phase_2_with_survey_8020.csv', index=False)

print("Forecast results have been written to arima_phase_1_with_survey_8020.csv")
# Out:
# 1 Processing ID: Exp_3928
# 2 Processing ID: Exp_3921
# 3 Processing ID: Exp_3913
# 4 Processing ID: Exp_3917
# 5 Processing ID: Exp_3884
# 6 Processing ID: Exp_3901
# 7 Processing ID: Exp_3889
# 8 Processing ID: Exp_3843
# 9 Processing ID: Exp_3924
# 10 Processing ID: Exp_3935
# 11 Processing ID: Exp_3874
# 12 Processing ID: Exp_3887
# 13 Processing ID: Exp_3866
# 14 Processing ID: Exp_3841
# 15 Processing ID: Exp_3850
# 16 Processing ID: Exp_3886
# 17 Processing ID: Exp_3915
# 18 Processing ID: Exp_3875
# 19 Processing ID: Exp_3882
# 20 Processing ID: Exp_3930
# 21 Processing ID: Exp_3906
# 22 Processing ID: Exp_3854
# 23 Processing ID: Exp_3936
# 24 Processing ID: Exp_3893
# 25 Processing ID: Exp_3898
# 26 Processing ID: Exp_3839
# 27 Processing ID: Exp_3938
# 28 Processing ID: Exp_3899
# 29 Processing ID: Exp_3933
# 30 Processing ID: Exp_3910
# 31 Processing ID: Exp_3862
# 32 Processing ID: Exp_3908
# 33 Processing ID: Exp_3863
# 34 Processing ID: Exp_3840
# 35 Processing ID: Exp_3888
# 36 Processing ID: Exp_3967
# 37 Processing ID: Exp_3926
# 38 Processing ID: Exp_3870
# 39 Processing ID: Exp_3958
# 40 Processing ID: Exp_3852
# 41 Processing ID: Exp_3842
# 42 Processing ID: Exp_3974
# 43 Processing ID: Exp_3972
# 44 Processing ID: Exp_3952
# 45 Processing ID: Exp_3846
# 46 Processing ID: Exp_3848
# 47 Processing ID: Exp_3975
# 48 Processing ID: Exp_3941
# 49 Processing ID: Exp_3194
# 50 Processing ID: Exp_3156
# 51 Processing ID: Exp_3248
# 52 Processing ID: Exp_3271
# 53 Processing ID: Exp_3258
# 54 Processing ID: Exp_3204
# 55 Processing ID: Exp_3188
# 56 Processing ID: Exp_3153
# 57 Processing ID: Exp_3157
# 58 Processing ID: Exp_3169
# 59 Processing ID: Exp_3206
# 60 Processing ID: Exp_3177
# 61 Processing ID: Exp_3186
# 62 Processing ID: Exp_3292
# 63 Processing ID: Exp_3151
# 64 Processing ID: Exp_3174
# 65 Processing ID: Exp_3209
# 66 Processing ID: Exp_3155
# 67 Processing ID: Exp_3228
# 68 Processing ID: Exp_3251
# 69 Processing ID: Exp_3154
# 70 Processing ID: Exp_3227
# 71 Processing ID: Exp_3232
# 72 Processing ID: Exp_3244
# 73 Processing ID: Exp_3172
# 74 Processing ID: Exp_3288
# 75 Processing ID: Exp_3245
# 76 Processing ID: Exp_3200
# 77 Processing ID: Exp_3262
# 78 Processing ID: Exp_3415
# 79 Processing ID: Exp_3418
# 80 Processing ID: Exp_3304
# 81 Processing ID: Exp_3300
# 82 Processing ID: Exp_3316
# 83 Processing ID: Exp_3379
# 84 Processing ID: Exp_3184
# 85 Processing ID: Exp_3158
# 86 Processing ID: Exp_3401
# 87 Processing ID: Exp_3356
# 88 Processing ID: Exp_3306
# 89 Processing ID: Exp_3387
# 90 Processing ID: Exp_3380
# 91 Processing ID: Exp_3365
# 92 Processing ID: Exp_3280
# 93 Processing ID: Exp_3374
# 94 Processing ID: Exp_3376
# 95 Processing ID: Exp_3355
# 96 Processing ID: Exp_3377
# 97 Processing ID: Exp_3389
# 98 Processing ID: Exp_3268
# 99 Processing ID: Exp_3386
# 100 Processing ID: Exp_3317
# 101 Processing ID: Exp_3385
# 102 Processing ID: Exp_3274
# 103 Processing ID: Exp_3269
# 104 Processing ID: Exp_3270
# 105 Processing ID: Exp_3276
# 106 Processing ID: Exp_3307
# 107 Processing ID: Exp_3361
# 108 Processing ID: Exp_3366
# 109 Processing ID: Exp_3393
# 110 Processing ID: Exp_3396
# 111 Processing ID: Exp_3399
# 112 Processing ID: Exp_3309
# 113 Processing ID: Exp_3342
# 114 Processing ID: Exp_3319
# 115 Processing ID: Exp_3338
# 116 Processing ID: Exp_3340
# 117 Processing ID: Exp_3333
# 118 Processing ID: Exp_3324
# 119 Processing ID: Exp_3318
# 120 Processing ID: Exp_3345
# 121 Processing ID: Exp_3337
# 122 Processing ID: Exp_3285
# 123 Processing ID: Exp_3281
# 124 Processing ID: Exp_3409
# 125 Processing ID: Exp_3390
# 126 Processing ID: Exp_3419
# 127 Processing ID: Exp_3410
# 128 Processing ID: Exp_3283
# 129 Processing ID: Exp_3351
# 130 Processing ID: Exp_3284
# 131 Processing ID: Exp_3312
# 132 Processing ID: Exp_3279
# 133 Processing ID: Exp_3331
# 134 Processing ID: Exp_3383
# 135 Processing ID: Exp_3164
# 136 Processing ID: Exp_3328
# 137 Processing ID: Exp_3175
# 138 Processing ID: Exp_3237
# 139 Processing ID: Exp_3311
# 140 Processing ID: Exp_3150
# 141 Processing ID: Exp_3303
# 142 Processing ID: Exp_3354
# 143 Processing ID: Exp_3191
# 144 Processing ID: Exp_3207
# 145 Processing ID: Exp_3369
# 146 Processing ID: Exp_3388
# 147 Processing ID: Exp_3171
# 148 Processing ID: Exp_3240
# 149 Processing ID: Exp_3243
# 150 Processing ID: Exp_3407
# 151 Processing ID: Exp_3291
# 152 Processing ID: Exp_3273
# 153 Processing ID: Exp_3414
# 154 Processing ID: Exp_3413
# 155 Processing ID: Exp_3256
# 156 Processing ID: Exp_3160
# 157 Processing ID: Exp_3234
# 158 Processing ID: Exp_3353
# 159 Processing ID: Exp_3170
# 160 Processing ID: Exp_3991
# 161 Processing ID: Exp_4175
# 162 Processing ID: Exp_4181
# 163 Processing ID: Exp_4182
# 164 Processing ID: Exp_4178
# 165 Processing ID: Exp_3993
# 166 Processing ID: Exp_3998
# 167 Processing ID: Exp_3996
# 168 Processing ID: Exp_3992
# 169 Processing ID: Exp_4030
# 170 Processing ID: Exp_4019
# 171 Processing ID: Exp_4169
# 172 Processing ID: Exp_4045
# 173 Processing ID: Exp_4029
# 174 Processing ID: Exp_4042
# 175 Processing ID: Exp_4043
# 176 Processing ID: Exp_4034
# 177 Processing ID: Exp_4033
# 178 Processing ID: Exp_4032
# 179 Processing ID: Exp_4015
# 180 Processing ID: Exp_4012
# 181 Processing ID: Exp_4009
# 182 Processing ID: Exp_4002
# 183 Processing ID: Exp_4008
# 184 Processing ID: Exp_4003
# 185 Processing ID: Exp_4014
# 186 Processing ID: Exp_4046
# 187 Processing ID: Exp_4048
# 188 Processing ID: Exp_3999
# 189 Processing ID: Exp_4088
# 190 Processing ID: Exp_4070
# 191 Processing ID: Exp_4074
# 192 Processing ID: Exp_4081
# 193 Processing ID: Exp_4075
# 194 Processing ID: Exp_4090
# 195 Processing ID: Exp_4083
# 196 Processing ID: Exp_4071
# 197 Processing ID: Exp_4145
# 198 Processing ID: Exp_4165
# 199 Processing ID: Exp_4167
# 200 Processing ID: Exp_4150
# 201 Processing ID: Exp_4155
# 202 Processing ID: Exp_4140
# 203 Processing ID: Exp_4139
# 204 Processing ID: Exp_4138
# 205 Processing ID: Exp_4153
# 206 Processing ID: Exp_4161
# 207 Processing ID: Exp_4148
# 208 Processing ID: Exp_4137
# 209 Processing ID: Exp_4146
# 210 Processing ID: Exp_4147
# 211 Processing ID: Exp_4166
# 212 Processing ID: Exp_4098
# 213 Processing ID: Exp_4108
# 214 Processing ID: Exp_4050
# 215 Processing ID: Exp_4063
# 216 Processing ID: Exp_4107
# 217 Processing ID: Exp_4065
# 218 Processing ID: Exp_4112
# 219 Processing ID: Exp_4093
# 220 Processing ID: Exp_4129
# 221 Processing ID: Exp_4121
# 222 Processing ID: Exp_4053
# 223 Processing ID: Exp_4109
# 224 Processing ID: Exp_4092
# 225 Processing ID: Exp_4099
# 226 Processing ID: Exp_4119
# 227 Processing ID: Exp_4100
# 228 Processing ID: Exp_4054
# 229 Processing ID: Exp_4105
# 230 Processing ID: Exp_4114
# 231 Processing ID: Exp_4117
# 232 Processing ID: Exp_4005
# 233 Processing ID: Exp_4016
# 234 Processing ID: Exp_3987
# 235 Processing ID: Exp_3989
# 236 Processing ID: Exp_3834
# 237 Processing ID: Exp_3835
# 238 Processing ID: Exp_3988
# 239 Processing ID: Exp_3985
# 240 Processing ID: Exp_3986
# 241 Processing ID: Exp_3982
# 242 Processing ID: Exp_3984
# 243 Processing ID: Exp_3454
# 244 Processing ID: Exp_3445
# 245 Processing ID: Exp_3427
# 246 Processing ID: Exp_3563
# 247 Processing ID: Exp_3565
# 248 Processing ID: Exp_3507
# 249 Processing ID: Exp_3508
# 250 Processing ID: Exp_3459
# 251 Processing ID: Exp_3495
# 252 Processing ID: Exp_3494
# 253 Processing ID: Exp_3496
# 254 Processing ID: Exp_3460
# 255 Processing ID: Exp_3465
# 256 Processing ID: Exp_3506
# 257 Processing ID: Exp_3512
# 258 Processing ID: Exp_3511
# 259 Processing ID: Exp_3509
# 260 Processing ID: Exp_3517
# 261 Processing ID: Exp_3424
# 262 Processing ID: Exp_3420
# 263 Processing ID: Exp_3423
# 264 Processing ID: Exp_3426
# 265 Processing ID: Exp_3442
# 266 Processing ID: Exp_3425
# 267 Processing ID: Exp_3558
# 268 Processing ID: Exp_3554
# 269 Processing ID: Exp_3450
# 270 Processing ID: Exp_3560
# 271 Processing ID: Exp_3486
# 272 Processing ID: Exp_3487
# 273 Processing ID: Exp_3448
# 274 Processing ID: Exp_3462
# 275 Processing ID: Exp_3431
# 276 Processing ID: Exp_3515
# 277 Processing ID: Exp_3474
# 278 Processing ID: Exp_3485
# 279 Processing ID: Exp_3557
# 280 Processing ID: Exp_3433
# 281 Processing ID: Exp_3556
# 282 Processing ID: Exp_3583
# 283 Processing ID: Exp_3661
# 284 Processing ID: Exp_3659
# 285 Processing ID: Exp_3717
# 286 Processing ID: Exp_3712
# 287 Processing ID: Exp_3794
# 288 Processing ID: Exp_3680
# 289 Processing ID: Exp_3657
# 290 Processing ID: Exp_3706
# 291 Processing ID: Exp_3808
# 292 Processing ID: Exp_3816
# 293 Processing ID: Exp_3819
# 294 Processing ID: Exp_3820
# 295 Processing ID: Exp_3597
# 296 Processing ID: Exp_3695
# 297 Processing ID: Exp_3805
# 298 Processing ID: Exp_3782
# 299 Processing ID: Exp_3768
# 300 Processing ID: Exp_3722
# 301 Processing ID: Exp_3801
# 302 Processing ID: Exp_3671
# 303 Processing ID: Exp_3678
# 304 Processing ID: Exp_3596
# 305 Processing ID: Exp_3806
# 306 Processing ID: Exp_3812
# 307 Processing ID: Exp_3599
# 308 Processing ID: Exp_3704
# 309 Processing ID: Exp_3578
# 310 Processing ID: Exp_3701
# 311 Processing ID: Exp_3634
# 312 Processing ID: Exp_3595
# 313 Processing ID: Exp_3809
# 314 Processing ID: Exp_3609
# 315 Processing ID: Exp_3798
# 316 Processing ID: Exp_3723
# 317 Processing ID: Exp_3720
# 318 Processing ID: Exp_3787
# 319 Processing ID: Exp_3708
# 320 Processing ID: Exp_3572
# 321 Processing ID: Exp_3627
# 322 Processing ID: Exp_3826
# 323 Processing ID: Exp_3830
# 324 Processing ID: Exp_3831
# 325 Processing ID: Exp_3688
# 326 Processing ID: Exp_3681
# 327 Processing ID: Exp_3660
# 328 Processing ID: Exp_3675
# 329 Processing ID: Exp_3601
# 330 Processing ID: Exp_3690
# 331 Processing ID: Exp_3725
# 332 Processing ID: Exp_3761
# 333 Processing ID: Exp_3762
# 334 Processing ID: Exp_3774
# 335 Processing ID: Exp_3763
# 336 Processing ID: Exp_3691
# 337 Processing ID: Exp_3696
# 338 Processing ID: Exp_3818
# 339 Processing ID: Exp_3734
# 340 Processing ID: Exp_3713
# 341 Processing ID: Exp_3575
# 342 Processing ID: Exp_3751
# 343 Processing ID: Exp_3765
# 344 Processing ID: Exp_3757
# 345 Processing ID: Exp_3759
# 346 Processing ID: Exp_3760
# 347 Processing ID: Exp_3754
# 348 Processing ID: Exp_3756
# 349 Processing ID: Exp_3778
# 350 Processing ID: Exp_3714
# 351 Processing ID: Exp_3727
# 352 Processing ID: Exp_3719
# 353 Processing ID: Exp_3592
# 354 Processing ID: Exp_3705
# 355 Processing ID: Exp_3726
# 356 Processing ID: Exp_3724
# 357 Processing ID: Exp_3791
# 358 Processing ID: Exp_3633
# 359 Processing ID: Exp_3655
# 360 Processing ID: Exp_3602
# 361 Processing ID: Exp_3623
# 362 Processing ID: Exp_3619
# 363 Processing ID: Exp_3615
# 364 Processing ID: Exp_3613
# 365 Processing ID: Exp_3770
# 366 Processing ID: Exp_3789
# 367 Processing ID: Exp_3607
# 368 Processing ID: Exp_3626
# 369 Processing ID: Exp_3617
# 370 Processing ID: Exp_3621
# 371 Processing ID: Exp_3611
# 372 Processing ID: Exp_3603
# 373 Processing ID: Exp_3606
# 374 Processing ID: Exp_3682
# 375 Processing ID: Exp_3635
# 376 Processing ID: Exp_3773
# 377 Processing ID: Exp_3637
# 378 Processing ID: Exp_3630
# 379 Processing ID: Exp_3594
# 380 Processing ID: Exp_3709
# 381 Processing ID: Exp_3585
# 382 Processing ID: Exp_3732
# 383 Processing ID: Exp_2368
# 384 Processing ID: Exp_2105
# 385 Processing ID: Exp_1989
# 386 Processing ID: Exp_2056
# 387 Processing ID: Exp_2588
# 388 Processing ID: Exp_2069
# 389 Processing ID: Exp_2364
# 390 Processing ID: Exp_2644
# 391 Processing ID: Exp_2159
# 392 Processing ID: Exp_1940
# 393 Processing ID: Exp_1788
# 394 Processing ID: Exp_2493
# 395 Processing ID: Exp_1849
# 396 Processing ID: Exp_1838
# 397 Processing ID: Exp_2474
# 398 Processing ID: Exp_2589
# 399 Processing ID: Exp_1889
# 400 Processing ID: Exp_2290
# 401 Processing ID: Exp_2687
# 402 Processing ID: Exp_1926
# 403 Processing ID: Exp_2394
# 404 Processing ID: Exp_2619
# 405 Processing ID: Exp_2256
# 406 Processing ID: Exp_1844
# 407 Processing ID: Exp_2658
# 408 Processing ID: Exp_2100
# 409 Processing ID: Exp_2417
# 410 Processing ID: Exp_2026
# 411 Processing ID: Exp_1767
# 412 Processing ID: Exp_2586
# 413 Processing ID: Exp_2018
# 414 Processing ID: Exp_2451
# 415 Processing ID: Exp_1959
# 416 Processing ID: Exp_2005
# 417 Processing ID: Exp_2545
# 418 Processing ID: Exp_2007
# 419 Processing ID: Exp_1845
# 420 Processing ID: Exp_1743
# 421 Processing ID: Exp_2151
# 422 Processing ID: Exp_2076
# 423 Processing ID: Exp_1807
# 424 Processing ID: Exp_1785
# 425 Processing ID: Exp_2442
# 426 Processing ID: Exp_2327
# 427 Processing ID: Exp_2465
# 428 Processing ID: Exp_1973
# 429 Processing ID: Exp_2627
# 430 Processing ID: Exp_2480
# 431 Processing ID: Exp_2683
# 432 Processing ID: Exp_2604
# 433 Processing ID: Exp_1742
# 434 Processing ID: Exp_2259
# 435 Processing ID: Exp_1981
# 436 Processing ID: Exp_2187
# 437 Processing ID: Exp_2086
# 438 Processing ID: Exp_1810
# 439 Processing ID: Exp_1738
# 440 Processing ID: Exp_2661
# 441 Processing ID: Exp_2053
# 442 Processing ID: Exp_1813
# 443 Processing ID: Exp_1829
# 444 Processing ID: Exp_2261
# 445 Processing ID: Exp_2315
# 446 Processing ID: Exp_2444
# 447 Processing ID: Exp_2294
# 448 Processing ID: Exp_2542
# 449 Processing ID: Exp_2272
# 450 Processing ID: Exp_1856
# 451 Processing ID: Exp_1965
# 452 Processing ID: Exp_2039
# 453 Processing ID: Exp_1887
# 454 Processing ID: Exp_2020
# 455 Processing ID: Exp_2087
# 456 Processing ID: Exp_2741
# 457 Processing ID: Exp_2079
# 458 Processing ID: Exp_1811
# 459 Processing ID: Exp_1781
# 460 Processing ID: Exp_2283
# 461 Processing ID: Exp_1798
# 462 Processing ID: Exp_1736
# 463 Processing ID: Exp_2045
# 464 Processing ID: Exp_1922
# 465 Processing ID: Exp_2702
# 466 Processing ID: Exp_1766
# 467 Processing ID: Exp_2063
# 468 Processing ID: Exp_2655
# 469 Processing ID: Exp_2735
# 470 Processing ID: Exp_1923
# 471 Processing ID: Exp_1817
# 472 Processing ID: Exp_1977
# 473 Processing ID: Exp_2158
# 474 Processing ID: Exp_2339
# 475 Processing ID: Exp_1744
# 476 Processing ID: Exp_2212
# 477 Processing ID: Exp_2217
# 478 Processing ID: Exp_2061
# 479 Processing ID: Exp_1831
# 480 Processing ID: Exp_1852
# 481 Processing ID: Exp_1861
# 482 Processing ID: Exp_2219
# 483 Processing ID: Exp_1910
# 484 Processing ID: Exp_1912
# 485 Processing ID: Exp_1997
# 486 Processing ID: Exp_1755
# 487 Processing ID: Exp_2459
# 488 Processing ID: Exp_2253
# 489 Processing ID: Exp_2720
# 490 Processing ID: Exp_2385
# 491 Processing ID: Exp_2724
# 492 Processing ID: Exp_1794
# 493 Processing ID: Exp_2200
# 494 Processing ID: Exp_2089
# 495 Processing ID: Exp_1857
# 496 Processing ID: Exp_2196
# 497 Processing ID: Exp_2210
# 498 Processing ID: Exp_2054
# 499 Processing ID: Exp_2514
# 500 Processing ID: Exp_2167
# 501 Processing ID: Exp_2279
# 502 Processing ID: Exp_1960
# 503 Processing ID: Exp_2293
# 504 Processing ID: Exp_2044
# 505 Processing ID: Exp_2556
# 506 Processing ID: Exp_2137
# 507 Processing ID: Exp_2659
# 508 Processing ID: Exp_2270
# 509 Processing ID: Exp_1731
# 510 Processing ID: Exp_2065
# 511 Processing ID: Exp_2500
# 512 Processing ID: Exp_2136
# 513 Processing ID: Exp_2222
# 514 Processing ID: Exp_1741
# 515 Processing ID: Exp_2013
# 516 Processing ID: Exp_1900
# 517 Processing ID: Exp_2521
# 518 Processing ID: Exp_2296
# 519 Processing ID: Exp_1999
# 520 Processing ID: Exp_1896
# 521 Processing ID: Exp_2260
# 522 Processing ID: Exp_2577
# 523 Processing ID: Exp_2538
# 524 Processing ID: Exp_2190
# 525 Processing ID: Exp_2198
# 526 Processing ID: Exp_1936
# 527 Processing ID: Exp_2440
# 528 Processing ID: Exp_2643
# 529 Processing ID: Exp_2023
# 530 Processing ID: Exp_2732
# 531 Processing ID: Exp_2325
# 532 Processing ID: Exp_1806
# 533 Processing ID: Exp_1992
# 534 Processing ID: Exp_1805
# 535 Processing ID: Exp_2238
# 536 Processing ID: Exp_1859
# 537 Processing ID: Exp_2561
# 538 Processing ID: Exp_2195
# 539 Processing ID: Exp_2050
# 540 Processing ID: Exp_1724
# 541 Processing ID: Exp_2708
# 542 Processing ID: Exp_2258
# 543 Processing ID: Exp_2024
# 544 Processing ID: Exp_2324
# 545 Processing ID: Exp_1969
# 546 Processing ID: Exp_1983
# 547 Processing ID: Exp_1978
# 548 Processing ID: Exp_2098
# 549 Processing ID: Exp_1836
# 550 Processing ID: Exp_2038
# 551 Processing ID: Exp_2478
# 552 Processing ID: Exp_2481
# 553 Processing ID: Exp_2463
# 554 Processing ID: Exp_2306
# 555 Processing ID: Exp_2019
# 556 Processing ID: Exp_2353
# 557 Processing ID: Exp_2081
# 558 Processing ID: Exp_2017
# 559 Processing ID: Exp_2330
# 560 Processing ID: Exp_1800
# 561 Processing ID: Exp_2374
# 562 Processing ID: Exp_1990
# 563 Processing ID: Exp_2208
# 564 Processing ID: Exp_2650
# 565 Processing ID: Exp_1909
# 566 Processing ID: Exp_2285
# 567 Processing ID: Exp_2326
# 568 Processing ID: Exp_2346
# 569 Processing ID: Exp_1917
# 570 Processing ID: Exp_2095
# 571 Processing ID: Exp_2160
# 572 Processing ID: Exp_2203
# 573 Processing ID: Exp_2559
# 574 Processing ID: Exp_2412
# 575 Processing ID: Exp_2426
# 576 Processing ID: Exp_2641
# 577 Processing ID: Exp_2341
# 578 Processing ID: Exp_2624
# 579 Processing ID: Exp_2233
# 580 Processing ID: Exp_2048
# 581 Processing ID: Exp_2573
# 582 Processing ID: Exp_2067
# 583 Processing ID: Exp_2334
# 584 Processing ID: Exp_2427
# 585 Processing ID: Exp_2607
# 586 Processing ID: Exp_2179
# 587 Processing ID: Exp_1771
# 588 Processing ID: Exp_2407
# 589 Processing ID: Exp_2275
# 590 Processing ID: Exp_2271
# 591 Processing ID: Exp_2671
# 592 Processing ID: Exp_2340
# 593 Processing ID: Exp_2322
# 594 Processing ID: Exp_2125
# 595 Processing ID: Exp_2464
# 596 Processing ID: Exp_2194
# 597 Processing ID: Exp_1848
# 598 Processing ID: Exp_2574
# 599 Processing ID: Exp_2593
# 600 Processing ID: Exp_2482
# 601 Processing ID: Exp_2584
# 602 Processing ID: Exp_1725
# 603 Processing ID: Exp_1918
# 604 Processing ID: Exp_1979
# 605 Processing ID: Exp_1768
# 606 Processing ID: Exp_1739
# 607 Processing ID: Exp_2597
# 608 Processing ID: Exp_2414
# 609 Processing ID: Exp_2114
# 610 Processing ID: Exp_2010
# 611 Processing ID: Exp_1945
# 612 Processing ID: Exp_2191
# 613 Processing ID: Exp_2642
# 614 Processing ID: Exp_2548
# 615 Processing ID: Exp_2116
# 616 Processing ID: Exp_2344
# 617 Processing ID: Exp_2681
# 618 Processing ID: Exp_2154
# 619 Processing ID: Exp_2526
# 620 Processing ID: Exp_2088
# 621 Processing ID: Exp_1905
# 622 Processing ID: Exp_2492
# 623 Processing ID: Exp_1757
# 624 Processing ID: Exp_2331
# 625 Processing ID: Exp_2347
# 626 Processing ID: Exp_1796
# 627 Processing ID: Exp_2723
# 628 Processing ID: Exp_2678
# 629 Processing ID: Exp_2622
# 630 Processing ID: Exp_1840
# 631 Processing ID: Exp_1971
# 632 Processing ID: Exp_1943
# 633 Processing ID: Exp_2656
# 634 Processing ID: Exp_2046
# 635 Processing ID: Exp_2403
# 636 Processing ID: Exp_2594
# 637 Processing ID: Exp_2102
# 638 Processing ID: Exp_2496
# 639 Processing ID: Exp_2180
# 640 Processing ID: Exp_1740
# 641 Processing ID: Exp_2236
# 642 Processing ID: Exp_2211
# 643 Processing ID: Exp_2395
# 644 Processing ID: Exp_1915
# 645 Processing ID: Exp_1894
# 646 Processing ID: Exp_1823
# 647 Processing ID: Exp_1832
# 648 Processing ID: Exp_2572
# 649 Processing ID: Exp_1826
# 650 Processing ID: Exp_1746
# 651 Processing ID: Exp_2077
# 652 Processing ID: Exp_2182
# 653 Processing ID: Exp_1921
# 654 Processing ID: Exp_1809
# 655 Processing ID: Exp_2528
# 656 Processing ID: Exp_1843
# 657 Processing ID: Exp_2376
# 658 Processing ID: Exp_1814
# 659 Processing ID: Exp_1747
# 660 Processing ID: Exp_2128
# 661 Processing ID: Exp_1916
# 662 Processing ID: Exp_2111
# 663 Processing ID: Exp_2505
# 664 Processing ID: Exp_1753
# 665 Processing ID: Exp_2059
# 666 Processing ID: Exp_2598
# 667 Processing ID: Exp_2582
# 668 Processing ID: Exp_2517
# 669 Processing ID: Exp_2071
# 670 Processing ID: Exp_2726
# 671 Processing ID: Exp_1729
# 672 Processing ID: Exp_1871
# 673 Processing ID: Exp_1791
# 674 Processing ID: Exp_1824
# 675 Processing ID: Exp_2639
# 676 Processing ID: Exp_1870
# 677 Processing ID: Exp_2541
# 678 Processing ID: Exp_1735
# 679 Processing ID: Exp_1884
# 680 Processing ID: Exp_1877
# 681 Processing ID: Exp_2469
# 682 Processing ID: Exp_1901
# 683 Processing ID: Exp_2612
# 684 Processing ID: Exp_2502
# 685 Processing ID: Exp_2552
# 686 Processing ID: Exp_2564
# 687 Processing ID: Exp_2091
# 688 Processing ID: Exp_2640
# 689 Processing ID: Exp_1879
# 690 Processing ID: Exp_2348
# 691 Processing ID: Exp_2689
# 692 Processing ID: Exp_2470
# 693 Processing ID: Exp_2277
# 694 Processing ID: Exp_2011
# 695 Processing ID: Exp_2555
# 696 Processing ID: Exp_2051
# 697 Processing ID: Exp_1939
# 698 Processing ID: Exp_2090
# 699 Processing ID: Exp_2460
# 700 Processing ID: Exp_2226
# 701 Processing ID: Exp_1830
# 702 Processing ID: Exp_2652
# 703 Processing ID: Exp_2072
# 704 Processing ID: Exp_2418
# 705 Processing ID: Exp_2524
# 706 Processing ID: Exp_2386
# 707 Processing ID: Exp_2600
# 708 Processing ID: Exp_1947
# 709 Processing ID: Exp_1750
# 710 Processing ID: Exp_2562
# 711 Processing ID: Exp_2008
# 712 Processing ID: Exp_2014
# 713 Processing ID: Exp_1885
# 714 Processing ID: Exp_2042
# 715 Processing ID: Exp_1891
# 716 Processing ID: Exp_1789
# 717 Processing ID: Exp_1772
# 718 Processing ID: Exp_1950
# 719 Processing ID: Exp_2432
# 720 Processing ID: Exp_2131
# 721 Processing ID: Exp_2049
# 722 Processing ID: Exp_1790
# 723 Processing ID: Exp_1935
# 724 Processing ID: Exp_2475
# 725 Processing ID: Exp_2716
# 726 Processing ID: Exp_1737
# 727 Processing ID: Exp_1822
# 728 Processing ID: Exp_2166
# 729 Processing ID: Exp_2197
# 730 Processing ID: Exp_2040
# 731 Processing ID: Exp_2307
# 732 Processing ID: Exp_1841
# 733 Processing ID: Exp_2099
# 734 Processing ID: Exp_1779
# 735 Processing ID: Exp_2433
# 736 Processing ID: Exp_2262
# 737 Processing ID: Exp_2411
# 738 Processing ID: Exp_2301
# 739 Processing ID: Exp_1765
# 740 Processing ID: Exp_2225
# 741 Processing ID: Exp_1975
# 742 Processing ID: Exp_2551
# 743 Processing ID: Exp_2068
# 744 Processing ID: Exp_2080
# 745 Processing ID: Exp_2740
# 746 Processing ID: Exp_1895
# 747 Processing ID: Exp_2408
# 748 Processing ID: Exp_2274
# 749 Processing ID: Exp_2428
# 750 Processing ID: Exp_2113
# 751 Processing ID: Exp_1828
# 752 Processing ID: Exp_2580
# 753 Processing ID: Exp_2047
# 754 Processing ID: Exp_1835
# 755 Processing ID: Exp_2121
# 756 Processing ID: Exp_4125
# 757 Processing ID: Exp_2342
# 758 Processing ID: Exp_2025
# 759 Processing ID: Exp_2156
# 760 Processing ID: Exp_2694
# 761 Processing ID: Exp_2727
# 762 Processing ID: Exp_4072
# 763 Processing ID: Exp_3458
# 764 Processing ID: Exp_1847
# 765 Processing ID: Exp_2736
# 766 Processing ID: Exp_2299
# 767 Processing ID: Exp_1968
# 768 Processing ID: Exp_2719
# 769 Processing ID: Exp_4118
# 770 Processing ID: Exp_4044
# 771 Processing ID: Exp_2616
# 772 Processing ID: Exp_4011
# 773 Processing ID: Exp_2691
# 774 Processing ID: Exp_2744
# 775 Processing ID: Exp_2662
# 776 Processing ID: Exp_2713
# 777 Processing ID: Exp_2176
# 778 Processing ID: Exp_4154
# 779 Processing ID: Exp_2633
# 780 Processing ID: Exp_2592
# 781 Processing ID: Exp_3748
# 782 Processing ID: Exp_3728
# 783 Processing ID: Exp_2183
# 784 Processing ID: Exp_2626
# 785 Processing ID: Exp_2446
# 786 Processing ID: Exp_2520
# 787 Processing ID: Exp_4036
# 788 Processing ID: Exp_1946
# 789 Processing ID: Exp_2057
# 790 Processing ID: Exp_2472
# 791 Processing ID: Exp_3796
# 792 Processing ID: Exp_3740
# 793 Processing ID: Exp_3497
# 794 Processing ID: Exp_3771
# 795 Processing ID: Exp_3510
# 796 Processing ID: Exp_3811
# 797 Processing ID: Exp_1944
# 798 Processing ID: Exp_1951
# 799 Processing ID: Exp_2637
# 800 Processing ID: Exp_2711
# 801 Processing ID: Exp_2070
# 802 Processing ID: Exp_3555
# 803 Processing ID: Exp_3646
# 804 Processing ID: Exp_2207
# 805 Processing ID: Exp_2677
# 806 Processing ID: Exp_2512
# 807 Processing ID: Exp_2513
# 808 Processing ID: Exp_2549
# 809 Processing ID: Exp_4136
# 810 Processing ID: Exp_4142
# 811 Processing ID: Exp_2610
# 812 Processing ID: Exp_2147
# 813 Processing ID: Exp_3579
# 814 Processing ID: Exp_4149
# 815 Processing ID: Exp_1749
# 816 Processing ID: Exp_2085
# 817 Processing ID: Exp_1994
# 818 Processing ID: Exp_1758
# 819 Processing ID: Exp_1860
# 820 Processing ID: Exp_2664
# 821 Processing ID: Exp_2119
# 822 Processing ID: Exp_2310
# 823 Processing ID: Exp_2097
# 824 Processing ID: Exp_4177
# 825 Processing ID: Exp_2363
# 826 Processing ID: Exp_4127
# 827 Processing ID: Exp_3647
# 828 Processing ID: Exp_1908
# 829 Processing ID: Exp_2043
# 830 Processing ID: Exp_3742
# 831 Processing ID: Exp_2532
# 832 Processing ID: Exp_2406
# 833 Processing ID: Exp_2032
# 834 Processing ID: Exp_3642
# 835 Processing ID: Exp_2004
# 836 Processing ID: Exp_3673
# 837 Processing ID: Exp_2145
# 838 Processing ID: Exp_3570
# 839 Processing ID: Exp_2239
# 840 Processing ID: Exp_3645
# 841 Processing ID: Exp_2718
# 842 Processing ID: Exp_1987
# 843 Processing ID: Exp_2297
# 844 Processing ID: Exp_3644
# 845 Processing ID: Exp_3455
# 846 Processing ID: Exp_2429
# 847 Processing ID: Exp_3652
# 848 Processing ID: Exp_2251
# 849 Processing ID: Exp_4176
# 850 Processing ID: Exp_2168
# 851 Processing ID: Exp_4157
# 852 Processing ID: Exp_1764
# 853 Processing ID: Exp_4164
# 854 Processing ID: Exp_3591
# 855 Processing ID: Exp_3783
# 856 Processing ID: Exp_2171
# 857 Processing ID: Exp_2250
# 858 Processing ID: Exp_2034
# 859 Processing ID: Exp_1988
# 860 Processing ID: Exp_1769
# 861 Processing ID: Exp_3824
# 862 Processing ID: Exp_3443
# 863 Processing ID: Exp_3473
# 864 Processing ID: Exp_2295
# 865 Processing ID: Exp_3745
# 866 Processing ID: Exp_1881
# 867 Processing ID: Exp_4079
# 868 Processing ID: Exp_3747
# 869 Processing ID: Exp_3775
# 870 Processing ID: Exp_2188
# 871 Processing ID: Exp_4073
# 872 Processing ID: Exp_1952
# 873 Processing ID: Exp_2537
# 874 Processing ID: Exp_2424
# 875 Processing ID: Exp_2135
# 876 Processing ID: Exp_2399
# 877 Processing ID: Exp_3464
# 878 Processing ID: Exp_2365
# 879 Processing ID: Exp_2133
# 880 Processing ID: Exp_2185
# 881 Processing ID: Exp_2381
# 882 Processing ID: Exp_2717
# 883 Processing ID: Exp_2001
# 884 Processing ID: Exp_3432
# 885 Processing ID: Exp_2576
# 886 Processing ID: Exp_2396
# 887 Processing ID: Exp_1996
# 888 Processing ID: Exp_2635
# 889 Processing ID: Exp_2672
# 890 Processing ID: Exp_2037
# 891 Processing ID: Exp_2300
# 892 Processing ID: Exp_2036
# 893 Processing ID: Exp_2437
# 894 Processing ID: Exp_2657
# 895 Processing ID: Exp_3640
# 896 Processing ID: Exp_2021
# 897 Processing ID: Exp_2585
# 898 Processing ID: Exp_2631
# 899 Processing ID: Exp_2491
# 900 Processing ID: Exp_2430
# 901 Processing ID: Exp_1906
# 902 Processing ID: Exp_2379
# 903 Processing ID: Exp_3466
# 904 Processing ID: Exp_2880
# 905 Processing ID: Exp_2948
# 906 Processing ID: Exp_3042
# 907 Processing ID: Exp_3103
# 908 Processing ID: Exp_3084
# 909 Processing ID: Exp_2906
# 910 Processing ID: Exp_2907
# 911 Processing ID: Exp_3100
# 912 Processing ID: Exp_3111
# 913 Processing ID: Exp_2962
# 914 Processing ID: Exp_3101
# 915 Processing ID: Exp_3069
# 916 Processing ID: Exp_2855
# 917 Processing ID: Exp_3082
# 918 Processing ID: Exp_2929
# 919 Processing ID: Exp_2897
# 920 Processing ID: Exp_2932
# 921 Processing ID: Exp_2911
# 922 Processing ID: Exp_3094
# 923 Processing ID: Exp_2937
# 924 Processing ID: Exp_2875
# 925 Processing ID: Exp_2981
# 926 Processing ID: Exp_2950
# 927 Processing ID: Exp_2904
# 928 Processing ID: Exp_2863
# 929 Processing ID: Exp_3033
# 930 Processing ID: Exp_2957
# 931 Processing ID: Exp_3102
# 932 Processing ID: Exp_2971
# 933 Processing ID: Exp_2939
# 934 Processing ID: Exp_2940
# 935 Processing ID: Exp_2871
# 936 Processing ID: Exp_2903
# 937 Processing ID: Exp_2979
# 938 Processing ID: Exp_3006
# 939 Processing ID: Exp_2861
# 940 Processing ID: Exp_3001
# 941 Processing ID: Exp_2878
# 942 Processing ID: Exp_3148
# 943 Processing ID: Exp_3075
# 944 Processing ID: Exp_2938
# 945 Processing ID: Exp_2945
# 946 Processing ID: Exp_2941
# 947 Processing ID: Exp_2967
# 948 Processing ID: Exp_3087
# 949 Processing ID: Exp_3138
# 950 Processing ID: Exp_3013
# 951 Processing ID: Exp_2965
# 952 Processing ID: Exp_2954
# 953 Processing ID: Exp_2854
# 954 Processing ID: Exp_2913
# 955 Processing ID: Exp_2992
# 956 Processing ID: Exp_3141
# 957 Processing ID: Exp_2921
# 958 Processing ID: Exp_2987
# 959 Processing ID: Exp_2885
# 960 Processing ID: Exp_2780
# 961 Processing ID: Exp_2781
# 962 Processing ID: Exp_3051
# 963 Processing ID: Exp_2917
# 964 Processing ID: Exp_3095
# 965 Processing ID: Exp_2997
# 966 Processing ID: Exp_2884
# 967 Processing ID: Exp_2918
# 968 Processing ID: Exp_3136
# 969 Processing ID: Exp_3021
# 970 Processing ID: Exp_2974
# 971 Processing ID: Exp_3048
# 972 Processing ID: Exp_3066
# 973 Processing ID: Exp_3030
# 974 Processing ID: Exp_3007
# 975 Processing ID: Exp_2898
# 976 Processing ID: Exp_3071
# 977 Processing ID: Exp_3120
# 978 Processing ID: Exp_2882
# 979 Processing ID: Exp_3147
# 980 Processing ID: Exp_3003
# 981 Processing ID: Exp_2872
# 982 Processing ID: Exp_2808
# 983 Processing ID: Exp_2811
# 984 Processing ID: Exp_2805
# 985 Processing ID: Exp_2816
# 986 Processing ID: Exp_2821
# 987 Processing ID: Exp_2814
# 988 Processing ID: Exp_2803
# 989 Processing ID: Exp_2778
# 990 Processing ID: Exp_2782
# 991 Processing ID: Exp_2783
# 992 Processing ID: Exp_2777
# 993 Processing ID: Exp_2793
# 994 Processing ID: Exp_2795
# 995 Processing ID: Exp_2839
# 996 Processing ID: Exp_2841
# 997 Processing ID: Exp_2836
# 998 Processing ID: Exp_2835
# 999 Processing ID: Exp_2845
# 1000 Processing ID: Exp_2851
# Overall MSE: 1.149068083503258
# Overall MAE: 0.6915350581285153
# Overall RMSE: 1.0719459331063568
# Forecast results have been written to arima_phase_1_with_survey_8020.csv

# %%
import pandas as pd
import pmdarima as pm
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import LabelEncoder
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# Load your dataset (assuming it is a CSV file)
df = pd.read_csv('phase_2_data_with_survey.csv')
df_clean = df.dropna()
# Convert 'Date' and 'Hour' columns to a datetime object
df_clean['Datetime'] = pd.to_datetime(df_clean['Date']) + pd.to_timedelta(df_clean['Hour'], unit='h')

# Set 'Datetime' as index
df_clean.set_index('Datetime', inplace=True)

# Encode categorical variables
label_encoder = LabelEncoder()
df_clean['home_size_encoded'] = label_encoder.fit_transform(df_clean['home_size'])
df_clean['electric_car_encoded'] = df_clean['electric_car'].map({'Yes': 1, 'No': 0})
df_clean['electrically_heated_encoded'] = df_clean['electrically_heated'].map({'Yes': 1, 'No': 0})

# List of exogenous variables
exog_vars = ['Temperature', 'home_size_encoded', 'electric_car_encoded', 'electrically_heated_encoded','no_of_people']

def fit_forecast_arima(df, split_ratio=0.6):
    ids = df['ID'].unique()[:1000]
    forecasts = []
    i = 1
    for id_ in ids:
        print(f"{i} Processing ID: {id_}")
        i += 1
        df_id = df[df['ID'] == id_].sort_index()

        # Split the data into train and test
        split_index = int(len(df_id) * split_ratio)
        train = df_id.iloc[:split_index]
        test = df_id.iloc[split_index:]

        # Fit the ARIMA model
        model = auto_arima(train['Demand_kWh'],
                           exogenous=train[exog_vars],
                           seasonal=False,
                           stepwise=True,
                           suppress_warnings=True,
                           trace=False)

        # Forecast
        n_periods = len(test)
        forecast = model.predict(n_periods=n_periods, exogenous=test[exog_vars])

        # Store the forecast and actual values
        forecast_df = pd.DataFrame({
            'ID': id_,
            'Datetime': test.index,
            'Actual_Demand': test['Demand_kWh'],
            'Predicted_Demand': forecast
        })

        forecasts.append(forecast_df)

    return pd.concat(forecasts)

# Run the forecasting function
results_df = fit_forecast_arima(df_clean)

# Calculate overall error metrics
mse = mean_squared_error(results_df['Actual_Demand'], results_df['Predicted_Demand'])
mae = mean_absolute_error(results_df['Actual_Demand'], results_df['Predicted_Demand'])
rmse = np.sqrt(mse)

print(f"Overall MSE: {mse}")
print(f"Overall MAE: {mae}")
print(f"Overall RMSE: {rmse}")

# Write the results to a file
results_df['Date'] = results_df['Datetime'].dt.date
results_df['Hour'] = results_df['Datetime'].dt.hour
results_df = results_df[['ID', 'Date', 'Hour', 'Actual_Demand', 'Predicted_Demand']]
results_df.to_csv('arima_phase_2_with_survey_6040.csv', index=False)

print("Forecast results have been written to arima_phase_1_with_survey_8020.csv")
# Out:
# 1 Processing ID: Exp_3928
# 2 Processing ID: Exp_3921
# 3 Processing ID: Exp_3913
# 4 Processing ID: Exp_3917
# 5 Processing ID: Exp_3884
# 6 Processing ID: Exp_3901
# 7 Processing ID: Exp_3889
# 8 Processing ID: Exp_3843
# 9 Processing ID: Exp_3924
# 10 Processing ID: Exp_3935
# 11 Processing ID: Exp_3874
# 12 Processing ID: Exp_3887
# 13 Processing ID: Exp_3866
# 14 Processing ID: Exp_3841
# 15 Processing ID: Exp_3850
# 16 Processing ID: Exp_3886
# 17 Processing ID: Exp_3915
# 18 Processing ID: Exp_3875
# 19 Processing ID: Exp_3882
# 20 Processing ID: Exp_3930
# 21 Processing ID: Exp_3906
# 22 Processing ID: Exp_3854
# 23 Processing ID: Exp_3936
# 24 Processing ID: Exp_3893
# 25 Processing ID: Exp_3898
# 26 Processing ID: Exp_3839
# 27 Processing ID: Exp_3938
# 28 Processing ID: Exp_3899
# 29 Processing ID: Exp_3933
# 30 Processing ID: Exp_3910
# 31 Processing ID: Exp_3862
# 32 Processing ID: Exp_3908
# 33 Processing ID: Exp_3863
# 34 Processing ID: Exp_3840
# 35 Processing ID: Exp_3888
# 36 Processing ID: Exp_3967
# 37 Processing ID: Exp_3926
# 38 Processing ID: Exp_3870
# 39 Processing ID: Exp_3958
# 40 Processing ID: Exp_3852
# 41 Processing ID: Exp_3842
# 42 Processing ID: Exp_3974
# 43 Processing ID: Exp_3972
# 44 Processing ID: Exp_3952
# 45 Processing ID: Exp_3846
# 46 Processing ID: Exp_3848
# 47 Processing ID: Exp_3975
# 48 Processing ID: Exp_3941
# 49 Processing ID: Exp_3194
# 50 Processing ID: Exp_3156
# 51 Processing ID: Exp_3248
# 52 Processing ID: Exp_3271
# 53 Processing ID: Exp_3258
# 54 Processing ID: Exp_3204
# 55 Processing ID: Exp_3188
# 56 Processing ID: Exp_3153
# 57 Processing ID: Exp_3157
# 58 Processing ID: Exp_3169
# 59 Processing ID: Exp_3206
# 60 Processing ID: Exp_3177
# 61 Processing ID: Exp_3186
# 62 Processing ID: Exp_3292
# 63 Processing ID: Exp_3151
# 64 Processing ID: Exp_3174
# 65 Processing ID: Exp_3209
# 66 Processing ID: Exp_3155
# 67 Processing ID: Exp_3228
# 68 Processing ID: Exp_3251
# 69 Processing ID: Exp_3154
# 70 Processing ID: Exp_3227
# 71 Processing ID: Exp_3232
# 72 Processing ID: Exp_3244
# 73 Processing ID: Exp_3172
# 74 Processing ID: Exp_3288
# 75 Processing ID: Exp_3245
# 76 Processing ID: Exp_3200
# 77 Processing ID: Exp_3262
# 78 Processing ID: Exp_3415
# 79 Processing ID: Exp_3418
# 80 Processing ID: Exp_3304
# 81 Processing ID: Exp_3300
# 82 Processing ID: Exp_3316
# 83 Processing ID: Exp_3379
# 84 Processing ID: Exp_3184
# 85 Processing ID: Exp_3158
# 86 Processing ID: Exp_3401
# 87 Processing ID: Exp_3356
# 88 Processing ID: Exp_3306
# 89 Processing ID: Exp_3387
# 90 Processing ID: Exp_3380
# 91 Processing ID: Exp_3365
# 92 Processing ID: Exp_3280
# 93 Processing ID: Exp_3374
# 94 Processing ID: Exp_3376
# 95 Processing ID: Exp_3355
# 96 Processing ID: Exp_3377
# 97 Processing ID: Exp_3389
# 98 Processing ID: Exp_3268
# 99 Processing ID: Exp_3386
# 100 Processing ID: Exp_3317
# 101 Processing ID: Exp_3385
# 102 Processing ID: Exp_3274
# 103 Processing ID: Exp_3269
# 104 Processing ID: Exp_3270
# 105 Processing ID: Exp_3276
# 106 Processing ID: Exp_3307
# 107 Processing ID: Exp_3361
# 108 Processing ID: Exp_3366
# 109 Processing ID: Exp_3393
# 110 Processing ID: Exp_3396
# 111 Processing ID: Exp_3399
# 112 Processing ID: Exp_3309
# 113 Processing ID: Exp_3342
# 114 Processing ID: Exp_3319
# 115 Processing ID: Exp_3338
# 116 Processing ID: Exp_3340
# 117 Processing ID: Exp_3333
# 118 Processing ID: Exp_3324
# 119 Processing ID: Exp_3318
# 120 Processing ID: Exp_3345
# 121 Processing ID: Exp_3337
# 122 Processing ID: Exp_3285
# 123 Processing ID: Exp_3281
# 124 Processing ID: Exp_3409
# 125 Processing ID: Exp_3390
# 126 Processing ID: Exp_3419
# 127 Processing ID: Exp_3410
# 128 Processing ID: Exp_3283
# 129 Processing ID: Exp_3351
# 130 Processing ID: Exp_3284
# 131 Processing ID: Exp_3312
# 132 Processing ID: Exp_3279
# 133 Processing ID: Exp_3331
# 134 Processing ID: Exp_3383
# 135 Processing ID: Exp_3164
# 136 Processing ID: Exp_3328
# 137 Processing ID: Exp_3175
# 138 Processing ID: Exp_3237
# 139 Processing ID: Exp_3311
# 140 Processing ID: Exp_3150
# 141 Processing ID: Exp_3303
# 142 Processing ID: Exp_3354
# 143 Processing ID: Exp_3191
# 144 Processing ID: Exp_3207
# 145 Processing ID: Exp_3369
# 146 Processing ID: Exp_3388
# 147 Processing ID: Exp_3171
# 148 Processing ID: Exp_3240
# 149 Processing ID: Exp_3243
# 150 Processing ID: Exp_3407
# 151 Processing ID: Exp_3291
# 152 Processing ID: Exp_3273
# 153 Processing ID: Exp_3414
# 154 Processing ID: Exp_3413
# 155 Processing ID: Exp_3256
# 156 Processing ID: Exp_3160
# 157 Processing ID: Exp_3234
# 158 Processing ID: Exp_3353
# 159 Processing ID: Exp_3170
# 160 Processing ID: Exp_3991
# 161 Processing ID: Exp_4175
# 162 Processing ID: Exp_4181
# 163 Processing ID: Exp_4182
# 164 Processing ID: Exp_4178
# 165 Processing ID: Exp_3993
# 166 Processing ID: Exp_3998
# 167 Processing ID: Exp_3996
# 168 Processing ID: Exp_3992
# 169 Processing ID: Exp_4030
# 170 Processing ID: Exp_4019
# 171 Processing ID: Exp_4169
# 172 Processing ID: Exp_4045
# 173 Processing ID: Exp_4029
# 174 Processing ID: Exp_4042
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 67
#      64     return pd.concat(forecasts)
#      66 # Run the forecasting function
# ---> 67 results_df = fit_forecast_arima(df_clean)
#      69 # Calculate overall error metrics
#      70 mse = mean_squared_error(results_df['Actual_Demand'], results_df['Predicted_Demand'])
#
# Cell In[7], line 52, in fit_forecast_arima(df, split_ratio)
#      50 # Forecast
#      51 n_periods = len(test)
# ---> 52 forecast = model.predict(n_periods=n_periods, exogenous=test[exog_vars])
#      54 # Store the forecast and actual values
#      55 forecast_df = pd.DataFrame({
#      56     'ID': id_,
#      57     'Datetime': test.index,
#      58     'Actual_Demand': test['Demand_kWh'],
#      59     'Predicted_Demand': forecast
#      60 })
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\arima.py:796, in ARIMA.predict(self, n_periods, X, return_conf_int, alpha, **kwargs)
#     793 arima = self.arima_res_
#     794 end = arima.nobs + n_periods - 1
# --> 796 f, conf_int = _seasonal_prediction_with_confidence(
#     797     arima_res=arima,
#     798     start=arima.nobs,
#     799     end=end,
#     800     X=X,
#     801     alpha=alpha)
#     803 if return_conf_int:
#     804     # The confidence intervals may be a Pandas frame if it comes from
#     805     # SARIMAX & we want Numpy. We will to duck type it so we don't add
#     806     # new explicit requirements for the package
#     807     return f, check_array(conf_int, force_all_finite=False)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\arima.py:205, in _seasonal_prediction_with_confidence(arima_res, start, end, X, alpha, **kwargs)
#     202     conf_int[:, 1] = f + q * np.sqrt(var)
#     204 y_pred = check_endog(f, dtype=None, copy=False, preserve_series=True)
# --> 205 conf_int = check_array(conf_int, copy=False, dtype=None)
#     207 return y_pred, conf_int
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df = pd.read_csv('phase_2_data_with_survey.csv')
df_cleaned = df[df['ID'].isna()]

# Display the cleaned DataFrame
print("\nCleaned DataFrame (rows with any value in 'id' dropped):")
print(df_cleaned)

# Write the cleaned DataFrame to a CSV file
df_cleaned.to_csv('phase_2_data_with_survey_cl.csv', index=False)

print("\nCleaned DataFrame has been written to 'cleaned_data.csv'")
# Out:
# Cleaned DataFrame (rows with any value in 'id' dropped):
# Empty DataFrame
# Columns: [ID, From, Date, Hour, Participation_Phase, Demand_kWh, Temperature, home_size, electric_car, no_of_people, electrically_heated]
# Index: []
#
# Cleaned DataFrame has been written to 'cleaned_data.csv'
